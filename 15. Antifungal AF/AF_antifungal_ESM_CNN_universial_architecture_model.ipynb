# %% [markdown]
# ### requirements for the following codings

# %%
### packages required 
# !pip install fair-esm 
# !pip install torch
# !pip install tensorflow
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 KB 1.3 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.8/dist-packages (2.11.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow) (23.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.30.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (23.1.21)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.12.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=4d05ad1eb61068445cf1c496dcd91fcaa57645758695529be1fa169868caa165
#   Stored in directory: /root/.cache/pip/wheels/14/25/f7/1cc0956978ae479e75140219088deb7a36f60459df242b1a72
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1

# %% [markdown]
# ### peptide embeddings with esm2_t6_8M_UR50D pretrained models
# 6 layers, 8M parameters, dataset: UR50/D 2021_04, embedding dimension: 320
# mode download URL: https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t6_8M_UR50D.pt

# %%
def esm_embeddings(peptide_sequence_list):
  # NOTICE: ESM for embeddings is quite RAM usage, if your sequence is too long, 
  #         or you have too many sequences for transformation in a single converting, 
  #         you conputer might automatically kill the job.
  import torch
  import esm
  import collections
  # load the model
  # NOTICE: if the model was not downloaded in your local environment, it will automatically download it.
  model, alphabet = esm.pretrained.esm2_t6_8M_UR50D()
  batch_converter = alphabet.get_batch_converter()
  model.eval()  # disables dropout for deterministic results

  # load the peptide sequence list into the bach_converter
  batch_labels, batch_strs, batch_tokens = batch_converter(peptide_sequence_list)
  batch_lens = (batch_tokens != alphabet.padding_idx).sum(1)
  ## batch tokens are the embedding results of the whole data set

  # Extract per-residue representations (on CPU)
  with torch.no_grad():
      # Here we export the last layer of the EMS model output as the representation of the peptides
      # model'esm2_t6_8M_UR50D' only has 6 layers, and therefore repr_layers parameters is equal to 6
      results = model(batch_tokens, repr_layers=[6], return_contacts=True)  
  token_representations = results["representations"][6]

  # Generate per-sequence representations via averaging
  # NOTE: token 0 is always a beginning-of-sequence token, so the first residue is token 1.
  sequence_representations = []
  for i, tokens_len in enumerate(batch_lens):
      sequence_representations.append(token_representations[i, 1 : tokens_len - 1].mean(0))
  # save dataset
  # sequence_representations is a list and each element is a tensor
  embeddings_results = collections.defaultdict(list)
  for i in range(len(sequence_representations)):
      # tensor can be transformed as numpy sequence_representations[0].numpy() or sequence_representations[0].to_list
      each_seq_rep = sequence_representations[i].tolist()
      for each_element in each_seq_rep:
          embeddings_results[i].append(each_element)
  embeddings_results = pd.DataFrame(embeddings_results).T
  return embeddings_results

# %% [markdown]
# ### data loading and embeddings

# %%
import numpy as np
import pandas as pd

# %%
# training dataset loading
dataset = pd.read_excel('AF_train.xlsx',na_filter = False) # take care the NA sequence problem
sequence_list = dataset['sequence'] 

embeddings_results = pd.DataFrame()
for seq in sequence_list:
    format_seq = [seq,seq] # the setting is just following the input format setting in ESM model, [name,sequence]
    tuple_sequence = tuple(format_seq)
    peptide_sequence_list = []
    peptide_sequence_list.append(tuple_sequence) # build a summarize list variable including all the sequence information
    # employ ESM model for converting and save the converted data in csv format
    one_seq_embeddings = esm_embeddings(peptide_sequence_list)
    embeddings_results= pd.concat([embeddings_results,one_seq_embeddings])

embeddings_results.to_csv('AF_train_esm2_t6_8M_UR50D_unified_320_dimension.csv')

# loading the y dataset for model development 
y_train = dataset['label']
y_train = np.array(y_train) # transformed as np.array for CNN model
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t6_8M_UR50D.pt" to /root/.cache/torch/hub/checkpoints/esm2_t6_8M_UR50D.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t6_8M_UR50D-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm2_t6_8M_UR50D-contact-regression.pt

# %%
# test dataset loading
dataset = pd.read_excel('AF_test.xlsx',na_filter = False) # take care the NA sequence problem
sequence_list = dataset['sequence'] 
embeddings_results = pd.DataFrame()
# embedding all the peptide one by one
for seq in sequence_list:
    format_seq = [seq,seq] # the setting is just following the input format setting in ESM model, [name,sequence]
    tuple_sequence = tuple(format_seq)
    peptide_sequence_list = []
    peptide_sequence_list.append(tuple_sequence) # build a summarize list variable including all the sequence information
    # employ ESM model for converting and save the converted data in csv format
    one_seq_embeddings = esm_embeddings(peptide_sequence_list)
    embeddings_results= pd.concat([embeddings_results,one_seq_embeddings])

embeddings_results.to_csv('AF_test_esm2_t6_8M_UR50D_unified_320_dimension.csv')


# loading the y dataset for model development 
y_test = dataset['label']
y_test = np.array(y_test) # transformed as np.array for CNN model

# %%
# assign the dataset 
X_train_data_name = 'AF_train_esm2_t6_8M_UR50D_unified_320_dimension.csv'
X_train_data = pd.read_csv(X_train_data_name,header=0, index_col = 0,delimiter=',')

X_test_data_name = 'AF_test_esm2_t6_8M_UR50D_unified_320_dimension.csv'
X_test_data = pd.read_csv(X_test_data_name,header=0, index_col = 0,delimiter=',')

X_train = np.array(X_train_data)
X_test = np.array(X_test_data)

# normalize the X data range
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train) # normalize X to 0-1 range 
X_test = scaler.transform(X_test)

# %%
# check the dimension of the dataset before model development
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1556, 320)
# (430, 320)
# (1556,)
# (430,)

# %%
import joblib
scaler = MinMaxScaler()
scaler.fit(X_train)

joblib.dump(scaler, 'AF.joblib')
# Out:
# ['AF.joblib']

# %% [markdown]
# ### Model architecture

# %%
def ESM_CNN(X_train, y_train, X_test, y_test):
  from keras.layers import Input,InputLayer, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D,Conv1D
  from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, AveragePooling1D, MaxPooling1D
  from keras.models import Sequential,Model
  from keras.optimizers import SGD
  from keras.callbacks import ModelCheckpoint,LearningRateScheduler, EarlyStopping
  import keras
  from keras import backend as K
  inputShape=(320,1)
  input = Input(inputShape)
  x = Conv1D(128,(3),strides = (1),name='layer_conv1',padding='same')(input)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = MaxPooling1D((2), name='MaxPool1',padding="same")(x)
  x = Dropout(0.15)(x)
  x = Conv1D(32,(3),strides = (1),name='layer_conv2',padding='same')(input)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = MaxPooling1D((2), name='MaxPool2',padding="same")(x)
  x = Dropout(0.15)(x)
  x = Flatten()(x)
  x = Dense(64,activation = 'relu',name='fc1')(x)
  x = Dropout(0.15)(x)
  x = Dense(2,activation = 'softmax',name='fc2')(x)
  model = Model(inputs = input,outputs = x,name='Predict')
  # define SGD optimizer
  momentum = 0.5
  sgd = SGD(lr=0.01, momentum=momentum, decay=0.0, nesterov=False)
  # compile the model
  model.compile(loss='sparse_categorical_crossentropy',optimizer=sgd, metrics=['accuracy'])
  # learning deccay setting
  import math
  def step_decay(epoch): # gradually decrease the learning rate 
      initial_lrate=0.1
      drop=0.6
      epochs_drop = 3.0
      lrate= initial_lrate * math.pow(drop,    # math.pow base raised to a power
            math.floor((1+epoch)/epochs_drop)) # math.floor Round numbers down to the nearest integer
      return lrate
  lrate = LearningRateScheduler(step_decay)

  # early stop setting
  early_stop = EarlyStopping(monitor='val_accuracy', patience = 40,restore_best_weights = True)

  # summary the callbacks_list
  callbacks_list = [ lrate , early_stop]

  model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                            epochs=200,callbacks=callbacks_list,batch_size = 16, verbose=2)
  return model, model_history

# %% [markdown]
# ### 10-fold cross validation

# %%
#Implementing 10-fold cross validation
from sklearn.model_selection import KFold
k = 10 
kf = KFold(n_splits=k, shuffle = True, random_state=1)
X_train = pd.DataFrame(X_train)
y_train = pd.DataFrame(y_train)

# result collection list
ACC_collecton = []
BACC_collecton = []
Sn_collecton = []
Sp_collecton = []
MCC_collecton = []
AUC_collecton = []

for train_index , test_index in kf.split(y_train):
    X_train_CV , X_valid_CV = X_train.iloc[train_index,:],X_train.iloc[test_index,:]
    y_train_CV , y_valid_CV = y_train.iloc[train_index] , y_train.iloc[test_index]
    model, model_history = ESM_CNN(X_train_CV, y_train_CV, X_valid_CV, y_valid_CV)
    # confusion matrix 
    predicted_class= []
    predicted_protability = model.predict(X_valid_CV,batch_size=1)
    for i in range(predicted_protability.shape[0]):
      index = np.where(predicted_protability[i] == np.amax(predicted_protability[i]))[0][0]
      predicted_class.append(index)
    predicted_class = np.array(predicted_class)
    y_true = y_valid_CV    
    from sklearn.metrics import confusion_matrix
    import math
    # np.ravel() return a flatten 1D array
    TP, FP, FN, TN = confusion_matrix(y_true, predicted_class).ravel() # shape [ [True-Positive, False-positive], [False-negative, True-negative] ]
    ACC = (TP+TN)/(TP+TN+FP+FN)
    ACC_collecton.append(ACC)
    Sn_collecton.append(TP/(TP+FN))
    Sp_collecton.append(TN/(TN+FP))
    MCC = (TP*TN-FP*FN)/math.pow(((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)),0.5)
    MCC_collecton.append(MCC)
    BACC_collecton.append(0.5*TP/(TP+FN)+0.5*TN/(TN+FP))
    from sklearn.metrics import roc_auc_score
    AUC = roc_auc_score(y_valid_CV, predicted_protability[:,1])
    AUC_collecton.append(AUC)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/200
# 88/88 - 2s - loss: 0.6810 - accuracy: 0.8236 - val_loss: 0.7826 - val_accuracy: 0.4872 - lr: 0.1000 - 2s/epoch - 26ms/step
# Epoch 2/200
# 88/88 - 1s - loss: 0.2370 - accuracy: 0.9121 - val_loss: 0.8057 - val_accuracy: 0.4872 - lr: 0.1000 - 977ms/epoch - 11ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1803 - accuracy: 0.9350 - val_loss: 0.6203 - val_accuracy: 0.5321 - lr: 0.0600 - 984ms/epoch - 11ms/step
# Epoch 4/200
# 88/88 - 1s - loss: 0.1795 - accuracy: 0.9300 - val_loss: 0.3422 - val_accuracy: 0.8974 - lr: 0.0600 - 1000ms/epoch - 11ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1629 - accuracy: 0.9343 - val_loss: 0.1936 - val_accuracy: 0.9231 - lr: 0.0600 - 968ms/epoch - 11ms/step
# Epoch 6/200
# 88/88 - 1s - loss: 0.1473 - accuracy: 0.9421 - val_loss: 0.1528 - val_accuracy: 0.9423 - lr: 0.0360 - 997ms/epoch - 11ms/step
# Epoch 7/200
# 88/88 - 1s - loss: 0.1398 - accuracy: 0.9493 - val_loss: 0.1321 - val_accuracy: 0.9359 - lr: 0.0360 - 985ms/epoch - 11ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.1286 - accuracy: 0.9521 - val_loss: 0.1179 - val_accuracy: 0.9487 - lr: 0.0360 - 985ms/epoch - 11ms/step
# Epoch 9/200
# 88/88 - 1s - loss: 0.1147 - accuracy: 0.9564 - val_loss: 0.1238 - val_accuracy: 0.9359 - lr: 0.0216 - 1s/epoch - 15ms/step
# Epoch 10/200
# 88/88 - 2s - loss: 0.1172 - accuracy: 0.9486 - val_loss: 0.1195 - val_accuracy: 0.9423 - lr: 0.0216 - 2s/epoch - 17ms/step
# Epoch 11/200
# 88/88 - 1s - loss: 0.1202 - accuracy: 0.9507 - val_loss: 0.1106 - val_accuracy: 0.9487 - lr: 0.0216 - 1s/epoch - 12ms/step
# Epoch 12/200
# 88/88 - 1s - loss: 0.1008 - accuracy: 0.9579 - val_loss: 0.1370 - val_accuracy: 0.9231 - lr: 0.0130 - 1s/epoch - 12ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0986 - accuracy: 0.9593 - val_loss: 0.1088 - val_accuracy: 0.9359 - lr: 0.0130 - 957ms/epoch - 11ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0920 - accuracy: 0.9593 - val_loss: 0.1033 - val_accuracy: 0.9423 - lr: 0.0130 - 975ms/epoch - 11ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.1027 - accuracy: 0.9550 - val_loss: 0.1029 - val_accuracy: 0.9423 - lr: 0.0078 - 995ms/epoch - 11ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0955 - accuracy: 0.9586 - val_loss: 0.1074 - val_accuracy: 0.9359 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 17/200
# 88/88 - 2s - loss: 0.1016 - accuracy: 0.9536 - val_loss: 0.1022 - val_accuracy: 0.9423 - lr: 0.0078 - 2s/epoch - 17ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0950 - accuracy: 0.9564 - val_loss: 0.1058 - val_accuracy: 0.9359 - lr: 0.0047 - 984ms/epoch - 11ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0948 - accuracy: 0.9571 - val_loss: 0.1061 - val_accuracy: 0.9359 - lr: 0.0047 - 986ms/epoch - 11ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0907 - accuracy: 0.9621 - val_loss: 0.1021 - val_accuracy: 0.9423 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 21/200
# 88/88 - 2s - loss: 0.0947 - accuracy: 0.9571 - val_loss: 0.1074 - val_accuracy: 0.9359 - lr: 0.0028 - 2s/epoch - 17ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0967 - accuracy: 0.9579 - val_loss: 0.1065 - val_accuracy: 0.9359 - lr: 0.0028 - 1s/epoch - 15ms/step
# Epoch 23/200
# 88/88 - 1s - loss: 0.0899 - accuracy: 0.9600 - val_loss: 0.1023 - val_accuracy: 0.9359 - lr: 0.0028 - 987ms/epoch - 11ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0929 - accuracy: 0.9593 - val_loss: 0.1046 - val_accuracy: 0.9359 - lr: 0.0017 - 958ms/epoch - 11ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0944 - accuracy: 0.9557 - val_loss: 0.1021 - val_accuracy: 0.9359 - lr: 0.0017 - 960ms/epoch - 11ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0888 - accuracy: 0.9614 - val_loss: 0.1060 - val_accuracy: 0.9359 - lr: 0.0017 - 970ms/epoch - 11ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0847 - accuracy: 0.9614 - val_loss: 0.1067 - val_accuracy: 0.9359 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0917 - accuracy: 0.9621 - val_loss: 0.1087 - val_accuracy: 0.9359 - lr: 0.0010 - 978ms/epoch - 11ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0854 - accuracy: 0.9636 - val_loss: 0.1080 - val_accuracy: 0.9359 - lr: 0.0010 - 984ms/epoch - 11ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0899 - accuracy: 0.9600 - val_loss: 0.1065 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 989ms/epoch - 11ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0876 - accuracy: 0.9629 - val_loss: 0.1064 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 1s/epoch - 14ms/step
# Epoch 32/200
# 88/88 - 2s - loss: 0.0817 - accuracy: 0.9621 - val_loss: 0.1055 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 2s/epoch - 20ms/step
# Epoch 33/200
# 88/88 - 2s - loss: 0.0906 - accuracy: 0.9614 - val_loss: 0.1056 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 2s/epoch - 20ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0823 - accuracy: 0.9629 - val_loss: 0.1055 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 1s/epoch - 15ms/step
# Epoch 35/200
# 88/88 - 1s - loss: 0.0886 - accuracy: 0.9593 - val_loss: 0.1063 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 975ms/epoch - 11ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0872 - accuracy: 0.9600 - val_loss: 0.1058 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 997ms/epoch - 11ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0899 - accuracy: 0.9579 - val_loss: 0.1066 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 1s/epoch - 11ms/step
# Epoch 38/200
# 88/88 - 1s - loss: 0.0864 - accuracy: 0.9593 - val_loss: 0.1063 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0846 - accuracy: 0.9614 - val_loss: 0.1060 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 969ms/epoch - 11ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0873 - accuracy: 0.9650 - val_loss: 0.1060 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 988ms/epoch - 11ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0888 - accuracy: 0.9636 - val_loss: 0.1061 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 1s/epoch - 11ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0834 - accuracy: 0.9636 - val_loss: 0.1060 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 960ms/epoch - 11ms/step
# Epoch 43/200
# 88/88 - 1s - loss: 0.0879 - accuracy: 0.9586 - val_loss: 0.1060 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 958ms/epoch - 11ms/step
# Epoch 44/200
# 88/88 - 1s - loss: 0.0886 - accuracy: 0.9600 - val_loss: 0.1062 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 1s/epoch - 12ms/step
# Epoch 45/200
# 88/88 - 2s - loss: 0.0871 - accuracy: 0.9593 - val_loss: 0.1063 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 2s/epoch - 17ms/step
# Epoch 46/200
# 88/88 - 1s - loss: 0.0850 - accuracy: 0.9600 - val_loss: 0.1063 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 1s/epoch - 14ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0893 - accuracy: 0.9579 - val_loss: 0.1061 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 968ms/epoch - 11ms/step
# Epoch 48/200
# 88/88 - 1s - loss: 0.0887 - accuracy: 0.9607 - val_loss: 0.1061 - val_accuracy: 0.9359 - lr: 2.8211e-05 - 1s/epoch - 11ms/step
# 156/156 [==============================] - 0s 2ms/step
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 88/88 - 2s - loss: 0.5696 - accuracy: 0.8664 - val_loss: 1.0921 - val_accuracy: 0.4551 - lr: 0.1000 - 2s/epoch - 22ms/step
# Epoch 2/200
# 88/88 - 2s - loss: 0.2325 - accuracy: 0.9179 - val_loss: 1.2809 - val_accuracy: 0.4551 - lr: 0.1000 - 2s/epoch - 18ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1907 - accuracy: 0.9286 - val_loss: 1.2386 - val_accuracy: 0.4551 - lr: 0.0600 - 1s/epoch - 14ms/step
# Epoch 4/200
# 88/88 - 1s - loss: 0.1703 - accuracy: 0.9414 - val_loss: 0.8886 - val_accuracy: 0.4679 - lr: 0.0600 - 1s/epoch - 11ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1521 - accuracy: 0.9464 - val_loss: 0.2829 - val_accuracy: 0.8846 - lr: 0.0600 - 1s/epoch - 11ms/step
# Epoch 6/200
# 88/88 - 1s - loss: 0.1311 - accuracy: 0.9536 - val_loss: 0.1756 - val_accuracy: 0.9359 - lr: 0.0360 - 977ms/epoch - 11ms/step
# Epoch 7/200
# 88/88 - 1s - loss: 0.1256 - accuracy: 0.9579 - val_loss: 0.2002 - val_accuracy: 0.9423 - lr: 0.0360 - 997ms/epoch - 11ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.1243 - accuracy: 0.9557 - val_loss: 0.2210 - val_accuracy: 0.9359 - lr: 0.0360 - 961ms/epoch - 11ms/step
# Epoch 9/200
# 88/88 - 1s - loss: 0.1072 - accuracy: 0.9650 - val_loss: 0.2298 - val_accuracy: 0.9423 - lr: 0.0216 - 1s/epoch - 12ms/step
# Epoch 10/200
# 88/88 - 1s - loss: 0.0998 - accuracy: 0.9657 - val_loss: 0.2535 - val_accuracy: 0.9359 - lr: 0.0216 - 968ms/epoch - 11ms/step
# Epoch 11/200
# 88/88 - 1s - loss: 0.0972 - accuracy: 0.9707 - val_loss: 0.2511 - val_accuracy: 0.9423 - lr: 0.0216 - 963ms/epoch - 11ms/step
# Epoch 12/200
# 88/88 - 1s - loss: 0.0894 - accuracy: 0.9700 - val_loss: 0.2663 - val_accuracy: 0.9359 - lr: 0.0130 - 996ms/epoch - 11ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0933 - accuracy: 0.9700 - val_loss: 0.2701 - val_accuracy: 0.9359 - lr: 0.0130 - 1s/epoch - 14ms/step
# Epoch 14/200
# 88/88 - 2s - loss: 0.0962 - accuracy: 0.9707 - val_loss: 0.2767 - val_accuracy: 0.9359 - lr: 0.0130 - 2s/epoch - 18ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.0756 - accuracy: 0.9764 - val_loss: 0.2822 - val_accuracy: 0.9359 - lr: 0.0078 - 1s/epoch - 13ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0788 - accuracy: 0.9764 - val_loss: 0.2894 - val_accuracy: 0.9359 - lr: 0.0078 - 994ms/epoch - 11ms/step
# Epoch 17/200
# 88/88 - 1s - loss: 0.0842 - accuracy: 0.9714 - val_loss: 0.2773 - val_accuracy: 0.9359 - lr: 0.0078 - 1s/epoch - 11ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0719 - accuracy: 0.9800 - val_loss: 0.2862 - val_accuracy: 0.9359 - lr: 0.0047 - 987ms/epoch - 11ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0723 - accuracy: 0.9807 - val_loss: 0.2923 - val_accuracy: 0.9359 - lr: 0.0047 - 1s/epoch - 11ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0764 - accuracy: 0.9779 - val_loss: 0.2927 - val_accuracy: 0.9359 - lr: 0.0047 - 1s/epoch - 11ms/step
# Epoch 21/200
# 88/88 - 1s - loss: 0.0706 - accuracy: 0.9793 - val_loss: 0.2980 - val_accuracy: 0.9359 - lr: 0.0028 - 993ms/epoch - 11ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0704 - accuracy: 0.9800 - val_loss: 0.2919 - val_accuracy: 0.9359 - lr: 0.0028 - 1s/epoch - 12ms/step
# Epoch 23/200
# 88/88 - 1s - loss: 0.0718 - accuracy: 0.9814 - val_loss: 0.3018 - val_accuracy: 0.9359 - lr: 0.0028 - 967ms/epoch - 11ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0708 - accuracy: 0.9829 - val_loss: 0.2986 - val_accuracy: 0.9359 - lr: 0.0017 - 964ms/epoch - 11ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0736 - accuracy: 0.9779 - val_loss: 0.2949 - val_accuracy: 0.9359 - lr: 0.0017 - 1s/epoch - 15ms/step
# Epoch 26/200
# 88/88 - 2s - loss: 0.0769 - accuracy: 0.9764 - val_loss: 0.2987 - val_accuracy: 0.9359 - lr: 0.0017 - 2s/epoch - 18ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0700 - accuracy: 0.9807 - val_loss: 0.2974 - val_accuracy: 0.9359 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0672 - accuracy: 0.9814 - val_loss: 0.2961 - val_accuracy: 0.9359 - lr: 0.0010 - 975ms/epoch - 11ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0705 - accuracy: 0.9764 - val_loss: 0.2960 - val_accuracy: 0.9359 - lr: 0.0010 - 994ms/epoch - 11ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0797 - accuracy: 0.9736 - val_loss: 0.2958 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 990ms/epoch - 11ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0784 - accuracy: 0.9786 - val_loss: 0.2961 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 967ms/epoch - 11ms/step
# Epoch 32/200
# 88/88 - 1s - loss: 0.0723 - accuracy: 0.9786 - val_loss: 0.2983 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 995ms/epoch - 11ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0684 - accuracy: 0.9807 - val_loss: 0.2990 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 1s/epoch - 11ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0680 - accuracy: 0.9800 - val_loss: 0.2980 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 965ms/epoch - 11ms/step
# Epoch 35/200
# 88/88 - 1s - loss: 0.0648 - accuracy: 0.9836 - val_loss: 0.2979 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 984ms/epoch - 11ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0631 - accuracy: 0.9829 - val_loss: 0.2981 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 988ms/epoch - 11ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0706 - accuracy: 0.9821 - val_loss: 0.2988 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 1s/epoch - 16ms/step
# Epoch 38/200
# 88/88 - 2s - loss: 0.0731 - accuracy: 0.9793 - val_loss: 0.2991 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 2s/epoch - 18ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0729 - accuracy: 0.9793 - val_loss: 0.2990 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 998ms/epoch - 11ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0740 - accuracy: 0.9786 - val_loss: 0.2987 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 963ms/epoch - 11ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0673 - accuracy: 0.9814 - val_loss: 0.2986 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 992ms/epoch - 11ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0693 - accuracy: 0.9814 - val_loss: 0.2983 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 979ms/epoch - 11ms/step
# Epoch 43/200
# 88/88 - 1s - loss: 0.0679 - accuracy: 0.9800 - val_loss: 0.2983 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 990ms/epoch - 11ms/step
# Epoch 44/200
# 88/88 - 1s - loss: 0.0743 - accuracy: 0.9779 - val_loss: 0.2986 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 988ms/epoch - 11ms/step
# Epoch 45/200
# 88/88 - 1s - loss: 0.0658 - accuracy: 0.9814 - val_loss: 0.2983 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 1s/epoch - 11ms/step
# Epoch 46/200
# 88/88 - 1s - loss: 0.0736 - accuracy: 0.9793 - val_loss: 0.2983 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 984ms/epoch - 11ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0671 - accuracy: 0.9814 - val_loss: 0.2984 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 987ms/epoch - 11ms/step
# 156/156 [==============================] - 0s 2ms/step
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 88/88 - 3s - loss: 0.7980 - accuracy: 0.8621 - val_loss: 0.6907 - val_accuracy: 0.5256 - lr: 0.1000 - 3s/epoch - 32ms/step
# Epoch 2/200
# 88/88 - 1s - loss: 0.1751 - accuracy: 0.9336 - val_loss: 0.6736 - val_accuracy: 0.5321 - lr: 0.1000 - 1s/epoch - 12ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1319 - accuracy: 0.9536 - val_loss: 0.5648 - val_accuracy: 0.9295 - lr: 0.0600 - 1s/epoch - 13ms/step
# Epoch 4/200
# 88/88 - 1s - loss: 0.1245 - accuracy: 0.9486 - val_loss: 0.3833 - val_accuracy: 0.9615 - lr: 0.0600 - 1s/epoch - 13ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1154 - accuracy: 0.9550 - val_loss: 0.2747 - val_accuracy: 0.9615 - lr: 0.0600 - 1s/epoch - 13ms/step
# Epoch 6/200
# 88/88 - 1s - loss: 0.0885 - accuracy: 0.9650 - val_loss: 0.1717 - val_accuracy: 0.9551 - lr: 0.0360 - 1s/epoch - 13ms/step
# Epoch 7/200
# 88/88 - 1s - loss: 0.0839 - accuracy: 0.9636 - val_loss: 0.1442 - val_accuracy: 0.9679 - lr: 0.0360 - 1s/epoch - 13ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.0846 - accuracy: 0.9629 - val_loss: 0.1333 - val_accuracy: 0.9679 - lr: 0.0360 - 1s/epoch - 14ms/step
# Epoch 9/200
# 88/88 - 1s - loss: 0.0767 - accuracy: 0.9650 - val_loss: 0.1536 - val_accuracy: 0.9679 - lr: 0.0216 - 1s/epoch - 16ms/step
# Epoch 10/200
# 88/88 - 2s - loss: 0.0649 - accuracy: 0.9721 - val_loss: 0.1540 - val_accuracy: 0.9679 - lr: 0.0216 - 2s/epoch - 23ms/step
# Epoch 11/200
# 88/88 - 2s - loss: 0.0699 - accuracy: 0.9693 - val_loss: 0.1304 - val_accuracy: 0.9615 - lr: 0.0216 - 2s/epoch - 18ms/step
# Epoch 12/200
# 88/88 - 1s - loss: 0.0592 - accuracy: 0.9764 - val_loss: 0.1465 - val_accuracy: 0.9679 - lr: 0.0130 - 1s/epoch - 16ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0572 - accuracy: 0.9750 - val_loss: 0.1510 - val_accuracy: 0.9551 - lr: 0.0130 - 1s/epoch - 12ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0594 - accuracy: 0.9729 - val_loss: 0.1652 - val_accuracy: 0.9679 - lr: 0.0130 - 992ms/epoch - 11ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.0514 - accuracy: 0.9793 - val_loss: 0.1681 - val_accuracy: 0.9679 - lr: 0.0078 - 1s/epoch - 11ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0592 - accuracy: 0.9693 - val_loss: 0.1618 - val_accuracy: 0.9615 - lr: 0.0078 - 1s/epoch - 11ms/step
# Epoch 17/200
# 88/88 - 1s - loss: 0.0494 - accuracy: 0.9757 - val_loss: 0.1678 - val_accuracy: 0.9679 - lr: 0.0078 - 987ms/epoch - 11ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0482 - accuracy: 0.9793 - val_loss: 0.1704 - val_accuracy: 0.9679 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0531 - accuracy: 0.9729 - val_loss: 0.1738 - val_accuracy: 0.9679 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0477 - accuracy: 0.9771 - val_loss: 0.1646 - val_accuracy: 0.9679 - lr: 0.0047 - 981ms/epoch - 11ms/step
# Epoch 21/200
# 88/88 - 1s - loss: 0.0528 - accuracy: 0.9757 - val_loss: 0.1675 - val_accuracy: 0.9679 - lr: 0.0028 - 992ms/epoch - 11ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0474 - accuracy: 0.9786 - val_loss: 0.1671 - val_accuracy: 0.9679 - lr: 0.0028 - 1s/epoch - 14ms/step
# Epoch 23/200
# 88/88 - 2s - loss: 0.0531 - accuracy: 0.9750 - val_loss: 0.1667 - val_accuracy: 0.9679 - lr: 0.0028 - 2s/epoch - 18ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0439 - accuracy: 0.9800 - val_loss: 0.1684 - val_accuracy: 0.9679 - lr: 0.0017 - 1s/epoch - 13ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0446 - accuracy: 0.9764 - val_loss: 0.1706 - val_accuracy: 0.9679 - lr: 0.0017 - 1s/epoch - 12ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0451 - accuracy: 0.9779 - val_loss: 0.1710 - val_accuracy: 0.9679 - lr: 0.0017 - 971ms/epoch - 11ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0416 - accuracy: 0.9821 - val_loss: 0.1686 - val_accuracy: 0.9679 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0488 - accuracy: 0.9771 - val_loss: 0.1678 - val_accuracy: 0.9679 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0473 - accuracy: 0.9771 - val_loss: 0.1699 - val_accuracy: 0.9679 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0456 - accuracy: 0.9764 - val_loss: 0.1704 - val_accuracy: 0.9679 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0498 - accuracy: 0.9750 - val_loss: 0.1707 - val_accuracy: 0.9679 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 32/200
# 88/88 - 1s - loss: 0.0447 - accuracy: 0.9786 - val_loss: 0.1721 - val_accuracy: 0.9679 - lr: 6.0466e-04 - 991ms/epoch - 11ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0412 - accuracy: 0.9786 - val_loss: 0.1721 - val_accuracy: 0.9679 - lr: 3.6280e-04 - 1s/epoch - 12ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0412 - accuracy: 0.9807 - val_loss: 0.1725 - val_accuracy: 0.9679 - lr: 3.6280e-04 - 1s/epoch - 17ms/step
# Epoch 35/200
# 88/88 - 2s - loss: 0.0480 - accuracy: 0.9750 - val_loss: 0.1722 - val_accuracy: 0.9679 - lr: 3.6280e-04 - 2s/epoch - 17ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0454 - accuracy: 0.9757 - val_loss: 0.1720 - val_accuracy: 0.9679 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0496 - accuracy: 0.9750 - val_loss: 0.1721 - val_accuracy: 0.9679 - lr: 2.1768e-04 - 1s/epoch - 11ms/step
# Epoch 38/200
# 88/88 - 1s - loss: 0.0448 - accuracy: 0.9779 - val_loss: 0.1721 - val_accuracy: 0.9679 - lr: 2.1768e-04 - 983ms/epoch - 11ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0484 - accuracy: 0.9771 - val_loss: 0.1717 - val_accuracy: 0.9679 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0433 - accuracy: 0.9779 - val_loss: 0.1719 - val_accuracy: 0.9679 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0465 - accuracy: 0.9764 - val_loss: 0.1716 - val_accuracy: 0.9679 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0484 - accuracy: 0.9771 - val_loss: 0.1715 - val_accuracy: 0.9679 - lr: 7.8364e-05 - 999ms/epoch - 11ms/step
# Epoch 43/200
# 88/88 - 1s - loss: 0.0483 - accuracy: 0.9779 - val_loss: 0.1716 - val_accuracy: 0.9679 - lr: 7.8364e-05 - 1s/epoch - 11ms/step
# Epoch 44/200
# 88/88 - 1s - loss: 0.0431 - accuracy: 0.9814 - val_loss: 0.1715 - val_accuracy: 0.9679 - lr: 7.8364e-05 - 1s/epoch - 11ms/step
# Epoch 45/200
# 88/88 - 1s - loss: 0.0426 - accuracy: 0.9793 - val_loss: 0.1712 - val_accuracy: 0.9679 - lr: 4.7018e-05 - 1s/epoch - 13ms/step
# Epoch 46/200
# 88/88 - 2s - loss: 0.0461 - accuracy: 0.9764 - val_loss: 0.1712 - val_accuracy: 0.9679 - lr: 4.7018e-05 - 2s/epoch - 18ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0407 - accuracy: 0.9800 - val_loss: 0.1715 - val_accuracy: 0.9679 - lr: 4.7018e-05 - 1s/epoch - 14ms/step
# 156/156 [==============================] - 0s 2ms/step
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 88/88 - 2s - loss: 0.7985 - accuracy: 0.8521 - val_loss: 0.6893 - val_accuracy: 0.4808 - lr: 0.1000 - 2s/epoch - 22ms/step
# Epoch 2/200
# 88/88 - 1s - loss: 0.1888 - accuracy: 0.9293 - val_loss: 0.6154 - val_accuracy: 0.5064 - lr: 0.1000 - 1s/epoch - 11ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1281 - accuracy: 0.9543 - val_loss: 0.5165 - val_accuracy: 0.8077 - lr: 0.0600 - 1s/epoch - 11ms/step
# Epoch 4/200
# 88/88 - 1s - loss: 0.1226 - accuracy: 0.9529 - val_loss: 0.2967 - val_accuracy: 0.9103 - lr: 0.0600 - 1s/epoch - 11ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1103 - accuracy: 0.9621 - val_loss: 0.1777 - val_accuracy: 0.9487 - lr: 0.0600 - 959ms/epoch - 11ms/step
# Epoch 6/200
# 88/88 - 1s - loss: 0.0940 - accuracy: 0.9657 - val_loss: 0.1575 - val_accuracy: 0.9359 - lr: 0.0360 - 1s/epoch - 12ms/step
# Epoch 7/200
# 88/88 - 1s - loss: 0.0862 - accuracy: 0.9679 - val_loss: 0.1467 - val_accuracy: 0.9423 - lr: 0.0360 - 1s/epoch - 11ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.0736 - accuracy: 0.9729 - val_loss: 0.1454 - val_accuracy: 0.9487 - lr: 0.0360 - 1s/epoch - 14ms/step
# Epoch 9/200
# 88/88 - 2s - loss: 0.0674 - accuracy: 0.9743 - val_loss: 0.1495 - val_accuracy: 0.9487 - lr: 0.0216 - 2s/epoch - 18ms/step
# Epoch 10/200
# 88/88 - 1s - loss: 0.0667 - accuracy: 0.9750 - val_loss: 0.1457 - val_accuracy: 0.9551 - lr: 0.0216 - 1s/epoch - 14ms/step
# Epoch 11/200
# 88/88 - 1s - loss: 0.0579 - accuracy: 0.9807 - val_loss: 0.1476 - val_accuracy: 0.9487 - lr: 0.0216 - 979ms/epoch - 11ms/step
# Epoch 12/200
# 88/88 - 1s - loss: 0.0563 - accuracy: 0.9807 - val_loss: 0.1472 - val_accuracy: 0.9487 - lr: 0.0130 - 973ms/epoch - 11ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0513 - accuracy: 0.9829 - val_loss: 0.1527 - val_accuracy: 0.9615 - lr: 0.0130 - 1s/epoch - 11ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0501 - accuracy: 0.9821 - val_loss: 0.1565 - val_accuracy: 0.9423 - lr: 0.0130 - 1s/epoch - 12ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.0467 - accuracy: 0.9836 - val_loss: 0.1509 - val_accuracy: 0.9487 - lr: 0.0078 - 979ms/epoch - 11ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0457 - accuracy: 0.9850 - val_loss: 0.1592 - val_accuracy: 0.9487 - lr: 0.0078 - 979ms/epoch - 11ms/step
# Epoch 17/200
# 88/88 - 1s - loss: 0.0490 - accuracy: 0.9807 - val_loss: 0.1552 - val_accuracy: 0.9551 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0409 - accuracy: 0.9864 - val_loss: 0.1601 - val_accuracy: 0.9487 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0449 - accuracy: 0.9850 - val_loss: 0.1608 - val_accuracy: 0.9487 - lr: 0.0047 - 1s/epoch - 11ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0442 - accuracy: 0.9843 - val_loss: 0.1604 - val_accuracy: 0.9487 - lr: 0.0047 - 1s/epoch - 17ms/step
# Epoch 21/200
# 88/88 - 2s - loss: 0.0447 - accuracy: 0.9821 - val_loss: 0.1583 - val_accuracy: 0.9487 - lr: 0.0028 - 2s/epoch - 18ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0419 - accuracy: 0.9843 - val_loss: 0.1587 - val_accuracy: 0.9487 - lr: 0.0028 - 986ms/epoch - 11ms/step
# Epoch 23/200
# 88/88 - 1s - loss: 0.0417 - accuracy: 0.9864 - val_loss: 0.1592 - val_accuracy: 0.9487 - lr: 0.0028 - 1s/epoch - 12ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0400 - accuracy: 0.9843 - val_loss: 0.1579 - val_accuracy: 0.9487 - lr: 0.0017 - 1s/epoch - 11ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0419 - accuracy: 0.9836 - val_loss: 0.1567 - val_accuracy: 0.9487 - lr: 0.0017 - 994ms/epoch - 11ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0370 - accuracy: 0.9886 - val_loss: 0.1589 - val_accuracy: 0.9487 - lr: 0.0017 - 1s/epoch - 11ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0430 - accuracy: 0.9857 - val_loss: 0.1591 - val_accuracy: 0.9487 - lr: 0.0010 - 990ms/epoch - 11ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0429 - accuracy: 0.9843 - val_loss: 0.1579 - val_accuracy: 0.9487 - lr: 0.0010 - 976ms/epoch - 11ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0402 - accuracy: 0.9871 - val_loss: 0.1580 - val_accuracy: 0.9487 - lr: 0.0010 - 977ms/epoch - 11ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0401 - accuracy: 0.9850 - val_loss: 0.1582 - val_accuracy: 0.9487 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0409 - accuracy: 0.9843 - val_loss: 0.1585 - val_accuracy: 0.9487 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 32/200
# 88/88 - 2s - loss: 0.0333 - accuracy: 0.9879 - val_loss: 0.1593 - val_accuracy: 0.9487 - lr: 6.0466e-04 - 2s/epoch - 18ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0379 - accuracy: 0.9871 - val_loss: 0.1590 - val_accuracy: 0.9487 - lr: 3.6280e-04 - 1s/epoch - 16ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0395 - accuracy: 0.9857 - val_loss: 0.1597 - val_accuracy: 0.9487 - lr: 3.6280e-04 - 996ms/epoch - 11ms/step
# Epoch 35/200
# 88/88 - 1s - loss: 0.0432 - accuracy: 0.9843 - val_loss: 0.1598 - val_accuracy: 0.9487 - lr: 3.6280e-04 - 1s/epoch - 12ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0391 - accuracy: 0.9871 - val_loss: 0.1602 - val_accuracy: 0.9487 - lr: 2.1768e-04 - 970ms/epoch - 11ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0389 - accuracy: 0.9857 - val_loss: 0.1602 - val_accuracy: 0.9487 - lr: 2.1768e-04 - 963ms/epoch - 11ms/step
# Epoch 38/200
# 88/88 - 1s - loss: 0.0377 - accuracy: 0.9864 - val_loss: 0.1604 - val_accuracy: 0.9487 - lr: 2.1768e-04 - 997ms/epoch - 11ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0370 - accuracy: 0.9879 - val_loss: 0.1604 - val_accuracy: 0.9487 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0402 - accuracy: 0.9829 - val_loss: 0.1606 - val_accuracy: 0.9487 - lr: 1.3061e-04 - 992ms/epoch - 11ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0387 - accuracy: 0.9857 - val_loss: 0.1606 - val_accuracy: 0.9487 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0385 - accuracy: 0.9836 - val_loss: 0.1604 - val_accuracy: 0.9487 - lr: 7.8364e-05 - 1s/epoch - 12ms/step
# Epoch 43/200
# 88/88 - 1s - loss: 0.0374 - accuracy: 0.9864 - val_loss: 0.1606 - val_accuracy: 0.9487 - lr: 7.8364e-05 - 1s/epoch - 14ms/step
# Epoch 44/200
# 88/88 - 2s - loss: 0.0360 - accuracy: 0.9879 - val_loss: 0.1607 - val_accuracy: 0.9487 - lr: 7.8364e-05 - 2s/epoch - 18ms/step
# Epoch 45/200
# 88/88 - 1s - loss: 0.0356 - accuracy: 0.9864 - val_loss: 0.1608 - val_accuracy: 0.9487 - lr: 4.7018e-05 - 1s/epoch - 13ms/step
# Epoch 46/200
# 88/88 - 1s - loss: 0.0417 - accuracy: 0.9821 - val_loss: 0.1608 - val_accuracy: 0.9487 - lr: 4.7018e-05 - 963ms/epoch - 11ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0402 - accuracy: 0.9829 - val_loss: 0.1607 - val_accuracy: 0.9487 - lr: 4.7018e-05 - 1s/epoch - 11ms/step
# Epoch 48/200
# 88/88 - 1s - loss: 0.0390 - accuracy: 0.9843 - val_loss: 0.1608 - val_accuracy: 0.9487 - lr: 2.8211e-05 - 978ms/epoch - 11ms/step
# Epoch 49/200
# 88/88 - 1s - loss: 0.0461 - accuracy: 0.9829 - val_loss: 0.1608 - val_accuracy: 0.9487 - lr: 2.8211e-05 - 1s/epoch - 12ms/step
# Epoch 50/200
# 88/88 - 1s - loss: 0.0415 - accuracy: 0.9814 - val_loss: 0.1605 - val_accuracy: 0.9487 - lr: 2.8211e-05 - 994ms/epoch - 11ms/step
# Epoch 51/200
# 88/88 - 1s - loss: 0.0392 - accuracy: 0.9850 - val_loss: 0.1605 - val_accuracy: 0.9487 - lr: 1.6927e-05 - 996ms/epoch - 11ms/step
# Epoch 52/200
# 88/88 - 1s - loss: 0.0372 - accuracy: 0.9857 - val_loss: 0.1606 - val_accuracy: 0.9487 - lr: 1.6927e-05 - 983ms/epoch - 11ms/step
# Epoch 53/200
# 88/88 - 1s - loss: 0.0345 - accuracy: 0.9879 - val_loss: 0.1605 - val_accuracy: 0.9487 - lr: 1.6927e-05 - 991ms/epoch - 11ms/step
# 156/156 [==============================] - 0s 2ms/step
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 88/88 - 3s - loss: 0.5552 - accuracy: 0.8479 - val_loss: 0.6946 - val_accuracy: 0.5128 - lr: 0.1000 - 3s/epoch - 30ms/step
# Epoch 2/200
# 88/88 - 1s - loss: 0.2211 - accuracy: 0.9164 - val_loss: 0.6964 - val_accuracy: 0.5128 - lr: 0.1000 - 1s/epoch - 14ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1791 - accuracy: 0.9336 - val_loss: 0.6884 - val_accuracy: 0.5128 - lr: 0.0600 - 1s/epoch - 12ms/step
# Epoch 4/200
# 88/88 - 1s - loss: 0.1585 - accuracy: 0.9329 - val_loss: 0.5746 - val_accuracy: 0.6538 - lr: 0.0600 - 1s/epoch - 12ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1464 - accuracy: 0.9414 - val_loss: 0.3696 - val_accuracy: 0.8846 - lr: 0.0600 - 1s/epoch - 12ms/step
# Epoch 6/200
# 88/88 - 1s - loss: 0.1224 - accuracy: 0.9543 - val_loss: 0.2443 - val_accuracy: 0.9038 - lr: 0.0360 - 986ms/epoch - 11ms/step
# Epoch 7/200
# 88/88 - 1s - loss: 0.1128 - accuracy: 0.9579 - val_loss: 0.2237 - val_accuracy: 0.9231 - lr: 0.0360 - 1s/epoch - 12ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.1100 - accuracy: 0.9536 - val_loss: 0.2393 - val_accuracy: 0.9295 - lr: 0.0360 - 1s/epoch - 11ms/step
# Epoch 9/200
# 88/88 - 1s - loss: 0.1001 - accuracy: 0.9636 - val_loss: 0.2538 - val_accuracy: 0.9359 - lr: 0.0216 - 1s/epoch - 15ms/step
# Epoch 10/200
# 88/88 - 2s - loss: 0.0951 - accuracy: 0.9664 - val_loss: 0.2630 - val_accuracy: 0.9295 - lr: 0.0216 - 2s/epoch - 18ms/step
# Epoch 11/200
# 88/88 - 2s - loss: 0.0901 - accuracy: 0.9664 - val_loss: 0.2784 - val_accuracy: 0.9359 - lr: 0.0216 - 2s/epoch - 18ms/step
# Epoch 12/200
# 88/88 - 2s - loss: 0.0794 - accuracy: 0.9700 - val_loss: 0.3072 - val_accuracy: 0.9231 - lr: 0.0130 - 2s/epoch - 18ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0808 - accuracy: 0.9664 - val_loss: 0.2853 - val_accuracy: 0.9423 - lr: 0.0130 - 1s/epoch - 12ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0836 - accuracy: 0.9657 - val_loss: 0.3069 - val_accuracy: 0.9231 - lr: 0.0130 - 996ms/epoch - 11ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.0726 - accuracy: 0.9679 - val_loss: 0.3017 - val_accuracy: 0.9423 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0717 - accuracy: 0.9757 - val_loss: 0.3115 - val_accuracy: 0.9423 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 17/200
# 88/88 - 1s - loss: 0.0706 - accuracy: 0.9757 - val_loss: 0.3187 - val_accuracy: 0.9359 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0751 - accuracy: 0.9700 - val_loss: 0.3057 - val_accuracy: 0.9359 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0724 - accuracy: 0.9743 - val_loss: 0.3254 - val_accuracy: 0.9423 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0622 - accuracy: 0.9800 - val_loss: 0.3300 - val_accuracy: 0.9423 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 21/200
# 88/88 - 1s - loss: 0.0611 - accuracy: 0.9736 - val_loss: 0.3367 - val_accuracy: 0.9359 - lr: 0.0028 - 1s/epoch - 12ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0683 - accuracy: 0.9721 - val_loss: 0.3343 - val_accuracy: 0.9423 - lr: 0.0028 - 1s/epoch - 13ms/step
# Epoch 23/200
# 88/88 - 2s - loss: 0.0633 - accuracy: 0.9771 - val_loss: 0.3321 - val_accuracy: 0.9359 - lr: 0.0028 - 2s/epoch - 18ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0628 - accuracy: 0.9800 - val_loss: 0.3349 - val_accuracy: 0.9423 - lr: 0.0017 - 1s/epoch - 14ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0612 - accuracy: 0.9764 - val_loss: 0.3366 - val_accuracy: 0.9423 - lr: 0.0017 - 991ms/epoch - 11ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0604 - accuracy: 0.9793 - val_loss: 0.3384 - val_accuracy: 0.9423 - lr: 0.0017 - 1s/epoch - 11ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0639 - accuracy: 0.9786 - val_loss: 0.3387 - val_accuracy: 0.9423 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0593 - accuracy: 0.9814 - val_loss: 0.3422 - val_accuracy: 0.9359 - lr: 0.0010 - 1s/epoch - 11ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0731 - accuracy: 0.9736 - val_loss: 0.3376 - val_accuracy: 0.9359 - lr: 0.0010 - 969ms/epoch - 11ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0598 - accuracy: 0.9757 - val_loss: 0.3395 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 1s/epoch - 11ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0618 - accuracy: 0.9764 - val_loss: 0.3405 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 980ms/epoch - 11ms/step
# Epoch 32/200
# 88/88 - 1s - loss: 0.0587 - accuracy: 0.9821 - val_loss: 0.3407 - val_accuracy: 0.9359 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0562 - accuracy: 0.9786 - val_loss: 0.3399 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 1s/epoch - 11ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0595 - accuracy: 0.9821 - val_loss: 0.3404 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 1s/epoch - 16ms/step
# Epoch 35/200
# 88/88 - 2s - loss: 0.0618 - accuracy: 0.9771 - val_loss: 0.3405 - val_accuracy: 0.9359 - lr: 3.6280e-04 - 2s/epoch - 18ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0585 - accuracy: 0.9814 - val_loss: 0.3409 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0611 - accuracy: 0.9786 - val_loss: 0.3415 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 976ms/epoch - 11ms/step
# Epoch 38/200
# 88/88 - 1s - loss: 0.0632 - accuracy: 0.9793 - val_loss: 0.3416 - val_accuracy: 0.9359 - lr: 2.1768e-04 - 992ms/epoch - 11ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0639 - accuracy: 0.9800 - val_loss: 0.3419 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0631 - accuracy: 0.9779 - val_loss: 0.3417 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0584 - accuracy: 0.9821 - val_loss: 0.3419 - val_accuracy: 0.9359 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0567 - accuracy: 0.9829 - val_loss: 0.3418 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 1s/epoch - 12ms/step
# Epoch 43/200
# 88/88 - 1s - loss: 0.0614 - accuracy: 0.9771 - val_loss: 0.3417 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 1s/epoch - 11ms/step
# Epoch 44/200
# 88/88 - 1s - loss: 0.0625 - accuracy: 0.9786 - val_loss: 0.3421 - val_accuracy: 0.9359 - lr: 7.8364e-05 - 967ms/epoch - 11ms/step
# Epoch 45/200
# 88/88 - 1s - loss: 0.0655 - accuracy: 0.9771 - val_loss: 0.3423 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 1s/epoch - 11ms/step
# Epoch 46/200
# 88/88 - 2s - loss: 0.0603 - accuracy: 0.9779 - val_loss: 0.3425 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 2s/epoch - 18ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0604 - accuracy: 0.9843 - val_loss: 0.3427 - val_accuracy: 0.9359 - lr: 4.7018e-05 - 1s/epoch - 16ms/step
# Epoch 48/200
# 88/88 - 1s - loss: 0.0729 - accuracy: 0.9743 - val_loss: 0.3425 - val_accuracy: 0.9359 - lr: 2.8211e-05 - 989ms/epoch - 11ms/step
# Epoch 49/200
# 88/88 - 1s - loss: 0.0638 - accuracy: 0.9736 - val_loss: 0.3424 - val_accuracy: 0.9359 - lr: 2.8211e-05 - 1s/epoch - 12ms/step
# Epoch 50/200
# 88/88 - 1s - loss: 0.0613 - accuracy: 0.9771 - val_loss: 0.3426 - val_accuracy: 0.9359 - lr: 2.8211e-05 - 991ms/epoch - 11ms/step
# Epoch 51/200
# 88/88 - 1s - loss: 0.0622 - accuracy: 0.9771 - val_loss: 0.3427 - val_accuracy: 0.9359 - lr: 1.6927e-05 - 1s/epoch - 12ms/step
# Epoch 52/200
# 88/88 - 1s - loss: 0.0709 - accuracy: 0.9757 - val_loss: 0.3427 - val_accuracy: 0.9359 - lr: 1.6927e-05 - 1s/epoch - 12ms/step
# Epoch 53/200
# 88/88 - 1s - loss: 0.0558 - accuracy: 0.9814 - val_loss: 0.3431 - val_accuracy: 0.9359 - lr: 1.6927e-05 - 997ms/epoch - 11ms/step
# 156/156 [==============================] - 0s 2ms/step
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 88/88 - 2s - loss: 0.7658 - accuracy: 0.7950 - val_loss: 0.5813 - val_accuracy: 0.8269 - lr: 0.1000 - 2s/epoch - 21ms/step
# Epoch 2/200
# 88/88 - 1s - loss: 0.2400 - accuracy: 0.8936 - val_loss: 0.4840 - val_accuracy: 0.8846 - lr: 0.1000 - 987ms/epoch - 11ms/step
# Epoch 3/200
# 88/88 - 2s - loss: 0.1853 - accuracy: 0.9343 - val_loss: 0.3308 - val_accuracy: 0.9038 - lr: 0.0600 - 2s/epoch - 17ms/step
# Epoch 4/200
# 88/88 - 2s - loss: 0.1525 - accuracy: 0.9400 - val_loss: 0.2289 - val_accuracy: 0.9167 - lr: 0.0600 - 2s/epoch - 17ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1462 - accuracy: 0.9421 - val_loss: 0.1850 - val_accuracy: 0.9167 - lr: 0.0600 - 1s/epoch - 11ms/step
# Epoch 6/200
# 88/88 - 1s - loss: 0.1195 - accuracy: 0.9536 - val_loss: 0.1506 - val_accuracy: 0.9487 - lr: 0.0360 - 1s/epoch - 12ms/step
# Epoch 7/200
# 88/88 - 1s - loss: 0.1103 - accuracy: 0.9586 - val_loss: 0.1566 - val_accuracy: 0.9295 - lr: 0.0360 - 998ms/epoch - 11ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.0997 - accuracy: 0.9643 - val_loss: 0.1370 - val_accuracy: 0.9487 - lr: 0.0360 - 1s/epoch - 12ms/step
# Epoch 9/200
# 88/88 - 1s - loss: 0.0934 - accuracy: 0.9636 - val_loss: 0.1373 - val_accuracy: 0.9551 - lr: 0.0216 - 991ms/epoch - 11ms/step
# Epoch 10/200
# 88/88 - 1s - loss: 0.0840 - accuracy: 0.9700 - val_loss: 0.1409 - val_accuracy: 0.9423 - lr: 0.0216 - 980ms/epoch - 11ms/step
# Epoch 11/200
# 88/88 - 1s - loss: 0.0769 - accuracy: 0.9686 - val_loss: 0.1398 - val_accuracy: 0.9551 - lr: 0.0216 - 1s/epoch - 11ms/step
# Epoch 12/200
# 88/88 - 1s - loss: 0.0753 - accuracy: 0.9707 - val_loss: 0.1333 - val_accuracy: 0.9487 - lr: 0.0130 - 993ms/epoch - 11ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0725 - accuracy: 0.9729 - val_loss: 0.1320 - val_accuracy: 0.9615 - lr: 0.0130 - 979ms/epoch - 11ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0679 - accuracy: 0.9743 - val_loss: 0.1244 - val_accuracy: 0.9615 - lr: 0.0130 - 1s/epoch - 13ms/step
# Epoch 15/200
# 88/88 - 2s - loss: 0.0596 - accuracy: 0.9821 - val_loss: 0.1248 - val_accuracy: 0.9615 - lr: 0.0078 - 2s/epoch - 18ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0627 - accuracy: 0.9786 - val_loss: 0.1282 - val_accuracy: 0.9615 - lr: 0.0078 - 1s/epoch - 15ms/step
# Epoch 17/200
# 88/88 - 1s - loss: 0.0623 - accuracy: 0.9764 - val_loss: 0.1239 - val_accuracy: 0.9551 - lr: 0.0078 - 1s/epoch - 11ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0601 - accuracy: 0.9750 - val_loss: 0.1271 - val_accuracy: 0.9615 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0606 - accuracy: 0.9786 - val_loss: 0.1316 - val_accuracy: 0.9615 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0565 - accuracy: 0.9843 - val_loss: 0.1318 - val_accuracy: 0.9615 - lr: 0.0047 - 1s/epoch - 11ms/step
# Epoch 21/200
# 88/88 - 1s - loss: 0.0568 - accuracy: 0.9807 - val_loss: 0.1271 - val_accuracy: 0.9615 - lr: 0.0028 - 968ms/epoch - 11ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0549 - accuracy: 0.9807 - val_loss: 0.1265 - val_accuracy: 0.9615 - lr: 0.0028 - 1s/epoch - 11ms/step
# Epoch 23/200
# 88/88 - 1s - loss: 0.0580 - accuracy: 0.9779 - val_loss: 0.1249 - val_accuracy: 0.9615 - lr: 0.0028 - 986ms/epoch - 11ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0558 - accuracy: 0.9807 - val_loss: 0.1250 - val_accuracy: 0.9615 - lr: 0.0017 - 1s/epoch - 12ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0542 - accuracy: 0.9821 - val_loss: 0.1265 - val_accuracy: 0.9615 - lr: 0.0017 - 1s/epoch - 12ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0503 - accuracy: 0.9836 - val_loss: 0.1259 - val_accuracy: 0.9615 - lr: 0.0017 - 1s/epoch - 16ms/step
# Epoch 27/200
# 88/88 - 2s - loss: 0.0559 - accuracy: 0.9814 - val_loss: 0.1254 - val_accuracy: 0.9615 - lr: 0.0010 - 2s/epoch - 18ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0516 - accuracy: 0.9814 - val_loss: 0.1270 - val_accuracy: 0.9615 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0517 - accuracy: 0.9800 - val_loss: 0.1279 - val_accuracy: 0.9615 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0500 - accuracy: 0.9850 - val_loss: 0.1266 - val_accuracy: 0.9615 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0519 - accuracy: 0.9850 - val_loss: 0.1276 - val_accuracy: 0.9615 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 32/200
# 88/88 - 1s - loss: 0.0563 - accuracy: 0.9807 - val_loss: 0.1266 - val_accuracy: 0.9615 - lr: 6.0466e-04 - 973ms/epoch - 11ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0511 - accuracy: 0.9843 - val_loss: 0.1263 - val_accuracy: 0.9615 - lr: 3.6280e-04 - 985ms/epoch - 11ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0560 - accuracy: 0.9800 - val_loss: 0.1263 - val_accuracy: 0.9615 - lr: 3.6280e-04 - 1s/epoch - 11ms/step
# Epoch 35/200
# 88/88 - 1s - loss: 0.0507 - accuracy: 0.9843 - val_loss: 0.1258 - val_accuracy: 0.9615 - lr: 3.6280e-04 - 996ms/epoch - 11ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0524 - accuracy: 0.9814 - val_loss: 0.1258 - val_accuracy: 0.9615 - lr: 2.1768e-04 - 1s/epoch - 11ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0497 - accuracy: 0.9857 - val_loss: 0.1259 - val_accuracy: 0.9615 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 38/200
# 88/88 - 2s - loss: 0.0571 - accuracy: 0.9814 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 2.1768e-04 - 2s/epoch - 18ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0516 - accuracy: 0.9843 - val_loss: 0.1258 - val_accuracy: 0.9615 - lr: 1.3061e-04 - 1s/epoch - 15ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0497 - accuracy: 0.9821 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0577 - accuracy: 0.9764 - val_loss: 0.1258 - val_accuracy: 0.9615 - lr: 1.3061e-04 - 989ms/epoch - 11ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0544 - accuracy: 0.9800 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 7.8364e-05 - 999ms/epoch - 11ms/step
# Epoch 43/200
# 88/88 - 1s - loss: 0.0561 - accuracy: 0.9821 - val_loss: 0.1255 - val_accuracy: 0.9615 - lr: 7.8364e-05 - 989ms/epoch - 11ms/step
# Epoch 44/200
# 88/88 - 1s - loss: 0.0516 - accuracy: 0.9800 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 7.8364e-05 - 1s/epoch - 11ms/step
# Epoch 45/200
# 88/88 - 1s - loss: 0.0534 - accuracy: 0.9779 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 4.7018e-05 - 1s/epoch - 12ms/step
# Epoch 46/200
# 88/88 - 1s - loss: 0.0520 - accuracy: 0.9821 - val_loss: 0.1258 - val_accuracy: 0.9615 - lr: 4.7018e-05 - 974ms/epoch - 11ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0536 - accuracy: 0.9821 - val_loss: 0.1256 - val_accuracy: 0.9615 - lr: 4.7018e-05 - 1s/epoch - 12ms/step
# Epoch 48/200
# 88/88 - 1s - loss: 0.0485 - accuracy: 0.9857 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 2.8211e-05 - 1s/epoch - 12ms/step
# Epoch 49/200
# 88/88 - 1s - loss: 0.0486 - accuracy: 0.9843 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 2.8211e-05 - 1s/epoch - 15ms/step
# Epoch 50/200
# 88/88 - 2s - loss: 0.0471 - accuracy: 0.9829 - val_loss: 0.1258 - val_accuracy: 0.9615 - lr: 2.8211e-05 - 2s/epoch - 18ms/step
# Epoch 51/200
# 88/88 - 1s - loss: 0.0526 - accuracy: 0.9807 - val_loss: 0.1256 - val_accuracy: 0.9615 - lr: 1.6927e-05 - 1s/epoch - 12ms/step
# Epoch 52/200
# 88/88 - 1s - loss: 0.0552 - accuracy: 0.9829 - val_loss: 0.1256 - val_accuracy: 0.9615 - lr: 1.6927e-05 - 1s/epoch - 12ms/step
# Epoch 53/200
# 88/88 - 1s - loss: 0.0519 - accuracy: 0.9836 - val_loss: 0.1257 - val_accuracy: 0.9615 - lr: 1.6927e-05 - 981ms/epoch - 11ms/step
# 156/156 [==============================] - 0s 2ms/step
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 88/88 - 2s - loss: 0.5680 - accuracy: 0.8301 - val_loss: 0.7018 - val_accuracy: 0.4774 - lr: 0.1000 - 2s/epoch - 21ms/step
# Epoch 2/200
# 88/88 - 1s - loss: 0.2224 - accuracy: 0.9136 - val_loss: 0.7640 - val_accuracy: 0.4774 - lr: 0.1000 - 990ms/epoch - 11ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1767 - accuracy: 0.9350 - val_loss: 0.7178 - val_accuracy: 0.4839 - lr: 0.0600 - 1s/epoch - 12ms/step
# Epoch 4/200
# 88/88 - 1s - loss: 0.1675 - accuracy: 0.9422 - val_loss: 0.6238 - val_accuracy: 0.5226 - lr: 0.0600 - 1s/epoch - 11ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1526 - accuracy: 0.9436 - val_loss: 0.3124 - val_accuracy: 0.8968 - lr: 0.0600 - 1s/epoch - 12ms/step
# Epoch 6/200
# 88/88 - 1s - loss: 0.1299 - accuracy: 0.9550 - val_loss: 0.1835 - val_accuracy: 0.9161 - lr: 0.0360 - 1s/epoch - 14ms/step
# Epoch 7/200
# 88/88 - 2s - loss: 0.1194 - accuracy: 0.9586 - val_loss: 0.1650 - val_accuracy: 0.9161 - lr: 0.0360 - 2s/epoch - 18ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.1226 - accuracy: 0.9557 - val_loss: 0.1556 - val_accuracy: 0.9161 - lr: 0.0360 - 1s/epoch - 13ms/step
# Epoch 9/200
# 88/88 - 1s - loss: 0.1030 - accuracy: 0.9586 - val_loss: 0.1580 - val_accuracy: 0.9226 - lr: 0.0216 - 980ms/epoch - 11ms/step
# Epoch 10/200
# 88/88 - 1s - loss: 0.1150 - accuracy: 0.9607 - val_loss: 0.1773 - val_accuracy: 0.9290 - lr: 0.0216 - 975ms/epoch - 11ms/step
# Epoch 11/200
# 88/88 - 1s - loss: 0.1034 - accuracy: 0.9643 - val_loss: 0.1733 - val_accuracy: 0.9355 - lr: 0.0216 - 1s/epoch - 11ms/step
# Epoch 12/200
# 88/88 - 1s - loss: 0.0957 - accuracy: 0.9672 - val_loss: 0.1720 - val_accuracy: 0.9290 - lr: 0.0130 - 1s/epoch - 11ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0928 - accuracy: 0.9672 - val_loss: 0.1642 - val_accuracy: 0.9290 - lr: 0.0130 - 984ms/epoch - 11ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0870 - accuracy: 0.9693 - val_loss: 0.1685 - val_accuracy: 0.9355 - lr: 0.0130 - 1s/epoch - 11ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.0900 - accuracy: 0.9714 - val_loss: 0.1760 - val_accuracy: 0.9290 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0821 - accuracy: 0.9714 - val_loss: 0.1847 - val_accuracy: 0.9290 - lr: 0.0078 - 1s/epoch - 11ms/step
# Epoch 17/200
# 88/88 - 1s - loss: 0.0826 - accuracy: 0.9707 - val_loss: 0.1745 - val_accuracy: 0.9290 - lr: 0.0078 - 1000ms/epoch - 11ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0814 - accuracy: 0.9764 - val_loss: 0.1715 - val_accuracy: 0.9290 - lr: 0.0047 - 1s/epoch - 16ms/step
# Epoch 19/200
# 88/88 - 2s - loss: 0.0792 - accuracy: 0.9722 - val_loss: 0.1721 - val_accuracy: 0.9290 - lr: 0.0047 - 2s/epoch - 18ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0811 - accuracy: 0.9743 - val_loss: 0.1745 - val_accuracy: 0.9290 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 21/200
# 88/88 - 1s - loss: 0.0702 - accuracy: 0.9779 - val_loss: 0.1779 - val_accuracy: 0.9290 - lr: 0.0028 - 974ms/epoch - 11ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0870 - accuracy: 0.9686 - val_loss: 0.1759 - val_accuracy: 0.9290 - lr: 0.0028 - 1s/epoch - 12ms/step
# Epoch 23/200
# 88/88 - 1s - loss: 0.0772 - accuracy: 0.9750 - val_loss: 0.1770 - val_accuracy: 0.9355 - lr: 0.0028 - 991ms/epoch - 11ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0782 - accuracy: 0.9743 - val_loss: 0.1764 - val_accuracy: 0.9290 - lr: 0.0017 - 1s/epoch - 12ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0752 - accuracy: 0.9757 - val_loss: 0.1750 - val_accuracy: 0.9290 - lr: 0.0017 - 1s/epoch - 12ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0764 - accuracy: 0.9714 - val_loss: 0.1759 - val_accuracy: 0.9290 - lr: 0.0017 - 1s/epoch - 11ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0733 - accuracy: 0.9764 - val_loss: 0.1768 - val_accuracy: 0.9290 - lr: 0.0010 - 989ms/epoch - 11ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0732 - accuracy: 0.9757 - val_loss: 0.1776 - val_accuracy: 0.9290 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0762 - accuracy: 0.9750 - val_loss: 0.1778 - val_accuracy: 0.9290 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 30/200
# 88/88 - 2s - loss: 0.0750 - accuracy: 0.9743 - val_loss: 0.1782 - val_accuracy: 0.9290 - lr: 6.0466e-04 - 2s/epoch - 18ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0712 - accuracy: 0.9764 - val_loss: 0.1770 - val_accuracy: 0.9290 - lr: 6.0466e-04 - 1s/epoch - 15ms/step
# Epoch 32/200
# 88/88 - 1s - loss: 0.0698 - accuracy: 0.9757 - val_loss: 0.1790 - val_accuracy: 0.9290 - lr: 6.0466e-04 - 1s/epoch - 11ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0713 - accuracy: 0.9764 - val_loss: 0.1781 - val_accuracy: 0.9290 - lr: 3.6280e-04 - 1s/epoch - 12ms/step
# ...
# Epoch 34/200
# 88/88 - 1s - loss: 0.0604 - accuracy: 0.9786 - val_loss: 0.2264 - val_accuracy: 0.9290 - lr: 3.6280e-04 - 1s/epoch - 12ms/step
# Epoch 35/200
# 88/88 - 1s - loss: 0.0644 - accuracy: 0.9772 - val_loss: 0.2263 - val_accuracy: 0.9290 - lr: 3.6280e-04 - 1s/epoch - 12ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0619 - accuracy: 0.9779 - val_loss: 0.2265 - val_accuracy: 0.9290 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0615 - accuracy: 0.9743 - val_loss: 0.2267 - val_accuracy: 0.9290 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 38/200
# 88/88 - 1s - loss: 0.0597 - accuracy: 0.9793 - val_loss: 0.2265 - val_accuracy: 0.9290 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0613 - accuracy: 0.9793 - val_loss: 0.2266 - val_accuracy: 0.9290 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0531 - accuracy: 0.9807 - val_loss: 0.2267 - val_accuracy: 0.9290 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0578 - accuracy: 0.9800 - val_loss: 0.2266 - val_accuracy: 0.9290 - lr: 1.3061e-04 - 1s/epoch - 12ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0607 - accuracy: 0.9764 - val_loss: 0.2267 - val_accuracy: 0.9290 - lr: 7.8364e-05 - 1s/epoch - 16ms/step
# Epoch 43/200
# 88/88 - 2s - loss: 0.0585 - accuracy: 0.9800 - val_loss: 0.2267 - val_accuracy: 0.9290 - lr: 7.8364e-05 - 2s/epoch - 19ms/step
# Epoch 44/200
# 88/88 - 1s - loss: 0.0546 - accuracy: 0.9829 - val_loss: 0.2267 - val_accuracy: 0.9290 - lr: 7.8364e-05 - 1s/epoch - 12ms/step
# Epoch 45/200
# 88/88 - 1s - loss: 0.0549 - accuracy: 0.9807 - val_loss: 0.2267 - val_accuracy: 0.9290 - lr: 4.7018e-05 - 1s/epoch - 12ms/step
# Epoch 46/200
# 88/88 - 1s - loss: 0.0567 - accuracy: 0.9793 - val_loss: 0.2269 - val_accuracy: 0.9290 - lr: 4.7018e-05 - 1s/epoch - 11ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0602 - accuracy: 0.9793 - val_loss: 0.2268 - val_accuracy: 0.9290 - lr: 4.7018e-05 - 1s/epoch - 11ms/step
# 155/155 [==============================] - 0s 2ms/step
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 88/88 - 2s - loss: 0.9105 - accuracy: 0.8708 - val_loss: 0.6985 - val_accuracy: 0.5161 - lr: 0.1000 - 2s/epoch - 22ms/step
# Epoch 2/200
# 88/88 - 1s - loss: 0.1833 - accuracy: 0.9243 - val_loss: 0.6990 - val_accuracy: 0.5161 - lr: 0.1000 - 1s/epoch - 11ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1513 - accuracy: 0.9400 - val_loss: 0.5993 - val_accuracy: 0.6194 - lr: 0.0600 - 1s/epoch - 12ms/step
# Epoch 4/200
# 88/88 - 1s - loss: 0.1405 - accuracy: 0.9436 - val_loss: 0.3234 - val_accuracy: 0.9355 - lr: 0.0600 - 1s/epoch - 12ms/step
# Epoch 5/200
# 88/88 - 1s - loss: 0.1263 - accuracy: 0.9479 - val_loss: 0.1444 - val_accuracy: 0.9613 - lr: 0.0600 - 1s/epoch - 16ms/step
# Epoch 6/200
# 88/88 - 2s - loss: 0.0941 - accuracy: 0.9622 - val_loss: 0.0848 - val_accuracy: 0.9742 - lr: 0.0360 - 2s/epoch - 18ms/step
# Epoch 7/200
# 88/88 - 1s - loss: 0.0946 - accuracy: 0.9622 - val_loss: 0.0762 - val_accuracy: 0.9677 - lr: 0.0360 - 1s/epoch - 12ms/step
# Epoch 8/200
# 88/88 - 1s - loss: 0.0907 - accuracy: 0.9650 - val_loss: 0.0615 - val_accuracy: 0.9742 - lr: 0.0360 - 1s/epoch - 12ms/step
# Epoch 9/200
# 88/88 - 1s - loss: 0.0775 - accuracy: 0.9650 - val_loss: 0.0650 - val_accuracy: 0.9742 - lr: 0.0216 - 1s/epoch - 11ms/step
# Epoch 10/200
# 88/88 - 1s - loss: 0.0747 - accuracy: 0.9693 - val_loss: 0.0787 - val_accuracy: 0.9613 - lr: 0.0216 - 1000ms/epoch - 11ms/step
# Epoch 11/200
# 88/88 - 1s - loss: 0.0694 - accuracy: 0.9722 - val_loss: 0.0572 - val_accuracy: 0.9806 - lr: 0.0216 - 1s/epoch - 12ms/step
# Epoch 12/200
# 88/88 - 1s - loss: 0.0637 - accuracy: 0.9736 - val_loss: 0.0595 - val_accuracy: 0.9742 - lr: 0.0130 - 1s/epoch - 11ms/step
# Epoch 13/200
# 88/88 - 1s - loss: 0.0630 - accuracy: 0.9750 - val_loss: 0.0628 - val_accuracy: 0.9677 - lr: 0.0130 - 1s/epoch - 12ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0692 - accuracy: 0.9707 - val_loss: 0.0646 - val_accuracy: 0.9742 - lr: 0.0130 - 1s/epoch - 11ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.0595 - accuracy: 0.9729 - val_loss: 0.0559 - val_accuracy: 0.9677 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 16/200
# 88/88 - 1s - loss: 0.0555 - accuracy: 0.9793 - val_loss: 0.0641 - val_accuracy: 0.9677 - lr: 0.0078 - 1s/epoch - 14ms/step
# Epoch 17/200
# 88/88 - 2s - loss: 0.0562 - accuracy: 0.9764 - val_loss: 0.0566 - val_accuracy: 0.9742 - lr: 0.0078 - 2s/epoch - 18ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0502 - accuracy: 0.9793 - val_loss: 0.0573 - val_accuracy: 0.9742 - lr: 0.0047 - 1s/epoch - 15ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0574 - accuracy: 0.9764 - val_loss: 0.0624 - val_accuracy: 0.9613 - lr: 0.0047 - 1s/epoch - 11ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0524 - accuracy: 0.9786 - val_loss: 0.0565 - val_accuracy: 0.9742 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 21/200
# 88/88 - 1s - loss: 0.0548 - accuracy: 0.9779 - val_loss: 0.0607 - val_accuracy: 0.9677 - lr: 0.0028 - 1000ms/epoch - 11ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0528 - accuracy: 0.9786 - val_loss: 0.0593 - val_accuracy: 0.9742 - lr: 0.0028 - 1s/epoch - 12ms/step
# Epoch 23/200
# 88/88 - 1s - loss: 0.0532 - accuracy: 0.9800 - val_loss: 0.0577 - val_accuracy: 0.9742 - lr: 0.0028 - 1s/epoch - 11ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0549 - accuracy: 0.9772 - val_loss: 0.0563 - val_accuracy: 0.9742 - lr: 0.0017 - 1s/epoch - 12ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0528 - accuracy: 0.9793 - val_loss: 0.0594 - val_accuracy: 0.9677 - lr: 0.0017 - 1s/epoch - 11ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0467 - accuracy: 0.9793 - val_loss: 0.0553 - val_accuracy: 0.9742 - lr: 0.0017 - 991ms/epoch - 11ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0501 - accuracy: 0.9786 - val_loss: 0.0576 - val_accuracy: 0.9742 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0537 - accuracy: 0.9793 - val_loss: 0.0569 - val_accuracy: 0.9742 - lr: 0.0010 - 1s/epoch - 17ms/step
# Epoch 29/200
# 88/88 - 2s - loss: 0.0492 - accuracy: 0.9814 - val_loss: 0.0574 - val_accuracy: 0.9742 - lr: 0.0010 - 2s/epoch - 18ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0499 - accuracy: 0.9814 - val_loss: 0.0567 - val_accuracy: 0.9742 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0503 - accuracy: 0.9814 - val_loss: 0.0570 - val_accuracy: 0.9742 - lr: 6.0466e-04 - 1s/epoch - 11ms/step
# Epoch 32/200
# 88/88 - 1s - loss: 0.0526 - accuracy: 0.9786 - val_loss: 0.0576 - val_accuracy: 0.9742 - lr: 6.0466e-04 - 993ms/epoch - 11ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0474 - accuracy: 0.9814 - val_loss: 0.0574 - val_accuracy: 0.9742 - lr: 3.6280e-04 - 1s/epoch - 12ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0489 - accuracy: 0.9829 - val_loss: 0.0574 - val_accuracy: 0.9742 - lr: 3.6280e-04 - 1s/epoch - 11ms/step
# Epoch 35/200
# 88/88 - 1s - loss: 0.0496 - accuracy: 0.9800 - val_loss: 0.0568 - val_accuracy: 0.9742 - lr: 3.6280e-04 - 1s/epoch - 12ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0444 - accuracy: 0.9822 - val_loss: 0.0565 - val_accuracy: 0.9742 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0530 - accuracy: 0.9779 - val_loss: 0.0563 - val_accuracy: 0.9742 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 38/200
# 88/88 - 1s - loss: 0.0471 - accuracy: 0.9793 - val_loss: 0.0562 - val_accuracy: 0.9742 - lr: 2.1768e-04 - 1s/epoch - 11ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0455 - accuracy: 0.9793 - val_loss: 0.0560 - val_accuracy: 0.9742 - lr: 1.3061e-04 - 1s/epoch - 13ms/step
# Epoch 40/200
# 88/88 - 2s - loss: 0.0510 - accuracy: 0.9800 - val_loss: 0.0558 - val_accuracy: 0.9742 - lr: 1.3061e-04 - 2s/epoch - 18ms/step
# Epoch 41/200
# 88/88 - 1s - loss: 0.0504 - accuracy: 0.9800 - val_loss: 0.0559 - val_accuracy: 0.9742 - lr: 1.3061e-04 - 1s/epoch - 14ms/step
# Epoch 42/200
# 88/88 - 1s - loss: 0.0548 - accuracy: 0.9807 - val_loss: 0.0560 - val_accuracy: 0.9742 - lr: 7.8364e-05 - 1s/epoch - 12ms/step
# Epoch 43/200
# 88/88 - 1s - loss: 0.0500 - accuracy: 0.9772 - val_loss: 0.0560 - val_accuracy: 0.9742 - lr: 7.8364e-05 - 1s/epoch - 12ms/step
# Epoch 44/200
# 88/88 - 1s - loss: 0.0527 - accuracy: 0.9793 - val_loss: 0.0560 - val_accuracy: 0.9742 - lr: 7.8364e-05 - 1s/epoch - 11ms/step
# Epoch 45/200
# 88/88 - 1s - loss: 0.0512 - accuracy: 0.9764 - val_loss: 0.0560 - val_accuracy: 0.9742 - lr: 4.7018e-05 - 1s/epoch - 11ms/step
# Epoch 46/200
# 88/88 - 1s - loss: 0.0541 - accuracy: 0.9764 - val_loss: 0.0560 - val_accuracy: 0.9742 - lr: 4.7018e-05 - 1s/epoch - 12ms/step
# Epoch 47/200
# 88/88 - 1s - loss: 0.0471 - accuracy: 0.9779 - val_loss: 0.0560 - val_accuracy: 0.9742 - lr: 4.7018e-05 - 1s/epoch - 12ms/step
# Epoch 48/200
# 88/88 - 1s - loss: 0.0494 - accuracy: 0.9807 - val_loss: 0.0561 - val_accuracy: 0.9742 - lr: 2.8211e-05 - 1s/epoch - 12ms/step
# Epoch 49/200
# 88/88 - 1s - loss: 0.0522 - accuracy: 0.9786 - val_loss: 0.0561 - val_accuracy: 0.9742 - lr: 2.8211e-05 - 1s/epoch - 12ms/step
# Epoch 50/200
# 88/88 - 1s - loss: 0.0513 - accuracy: 0.9786 - val_loss: 0.0561 - val_accuracy: 0.9742 - lr: 2.8211e-05 - 1s/epoch - 12ms/step
# Epoch 51/200
# 88/88 - 2s - loss: 0.0569 - accuracy: 0.9736 - val_loss: 0.0561 - val_accuracy: 0.9742 - lr: 1.6927e-05 - 2s/epoch - 17ms/step
# 155/155 [==============================] - 1s 7ms/step
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/200
# 88/88 - 4s - loss: 0.8130 - accuracy: 0.8251 - val_loss: 0.6419 - val_accuracy: 0.7419 - lr: 0.1000 - 4s/epoch - 43ms/step
# Epoch 2/200
# 88/88 - 2s - loss: 0.1965 - accuracy: 0.9229 - val_loss: 0.6574 - val_accuracy: 0.5484 - lr: 0.1000 - 2s/epoch - 19ms/step
# Epoch 3/200
# 88/88 - 1s - loss: 0.1476 - accuracy: 0.9422 - val_loss: 0.5462 - val_accuracy: 0.8710 - lr: 0.0600 - 1s/epoch - 17ms/step
# Epoch 4/200
# 88/88 - 2s - loss: 0.1197 - accuracy: 0.9472 - val_loss: 0.3794 - val_accuracy: 0.9355 - lr: 0.0600 - 2s/epoch - 20ms/step
# Epoch 5/200
# 88/88 - 2s - loss: 0.1225 - accuracy: 0.9458 - val_loss: 0.2114 - val_accuracy: 0.9226 - lr: 0.0600 - 2s/epoch - 28ms/step
# Epoch 6/200
# 88/88 - 2s - loss: 0.1054 - accuracy: 0.9607 - val_loss: 0.1498 - val_accuracy: 0.9613 - lr: 0.0360 - 2s/epoch - 24ms/step
# Epoch 7/200
# 88/88 - 2s - loss: 0.0931 - accuracy: 0.9600 - val_loss: 0.1307 - val_accuracy: 0.9419 - lr: 0.0360 - 2s/epoch - 19ms/step
# Epoch 8/200
# 88/88 - 2s - loss: 0.0908 - accuracy: 0.9707 - val_loss: 0.1373 - val_accuracy: 0.9613 - lr: 0.0360 - 2s/epoch - 18ms/step
# Epoch 9/200
# 88/88 - 2s - loss: 0.0837 - accuracy: 0.9700 - val_loss: 0.1398 - val_accuracy: 0.9355 - lr: 0.0216 - 2s/epoch - 22ms/step
# Epoch 10/200
# 88/88 - 2s - loss: 0.0774 - accuracy: 0.9700 - val_loss: 0.1345 - val_accuracy: 0.9419 - lr: 0.0216 - 2s/epoch - 22ms/step
# Epoch 11/200
# 88/88 - 2s - loss: 0.0769 - accuracy: 0.9736 - val_loss: 0.1320 - val_accuracy: 0.9484 - lr: 0.0216 - 2s/epoch - 17ms/step
# Epoch 12/200
# 88/88 - 2s - loss: 0.0645 - accuracy: 0.9757 - val_loss: 0.1418 - val_accuracy: 0.9484 - lr: 0.0130 - 2s/epoch - 17ms/step
# Epoch 13/200
# 88/88 - 2s - loss: 0.0646 - accuracy: 0.9736 - val_loss: 0.1393 - val_accuracy: 0.9484 - lr: 0.0130 - 2s/epoch - 19ms/step
# Epoch 14/200
# 88/88 - 1s - loss: 0.0570 - accuracy: 0.9772 - val_loss: 0.1483 - val_accuracy: 0.9355 - lr: 0.0130 - 1s/epoch - 12ms/step
# Epoch 15/200
# 88/88 - 1s - loss: 0.0557 - accuracy: 0.9786 - val_loss: 0.1523 - val_accuracy: 0.9355 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 16/200
# 88/88 - 2s - loss: 0.0523 - accuracy: 0.9807 - val_loss: 0.1490 - val_accuracy: 0.9419 - lr: 0.0078 - 2s/epoch - 20ms/step
# Epoch 17/200
# 88/88 - 1s - loss: 0.0558 - accuracy: 0.9772 - val_loss: 0.1579 - val_accuracy: 0.9419 - lr: 0.0078 - 1s/epoch - 12ms/step
# Epoch 18/200
# 88/88 - 1s - loss: 0.0474 - accuracy: 0.9814 - val_loss: 0.1611 - val_accuracy: 0.9484 - lr: 0.0047 - 990ms/epoch - 11ms/step
# Epoch 19/200
# 88/88 - 1s - loss: 0.0463 - accuracy: 0.9836 - val_loss: 0.1597 - val_accuracy: 0.9355 - lr: 0.0047 - 1s/epoch - 12ms/step
# Epoch 20/200
# 88/88 - 1s - loss: 0.0505 - accuracy: 0.9822 - val_loss: 0.1626 - val_accuracy: 0.9419 - lr: 0.0047 - 1s/epoch - 11ms/step
# Epoch 21/200
# 88/88 - 1s - loss: 0.0449 - accuracy: 0.9829 - val_loss: 0.1651 - val_accuracy: 0.9419 - lr: 0.0028 - 1s/epoch - 12ms/step
# Epoch 22/200
# 88/88 - 1s - loss: 0.0506 - accuracy: 0.9772 - val_loss: 0.1652 - val_accuracy: 0.9355 - lr: 0.0028 - 1s/epoch - 12ms/step
# Epoch 23/200
# 88/88 - 2s - loss: 0.0413 - accuracy: 0.9864 - val_loss: 0.1690 - val_accuracy: 0.9355 - lr: 0.0028 - 2s/epoch - 18ms/step
# Epoch 24/200
# 88/88 - 1s - loss: 0.0391 - accuracy: 0.9850 - val_loss: 0.1698 - val_accuracy: 0.9419 - lr: 0.0017 - 1s/epoch - 17ms/step
# Epoch 25/200
# 88/88 - 1s - loss: 0.0475 - accuracy: 0.9836 - val_loss: 0.1686 - val_accuracy: 0.9419 - lr: 0.0017 - 997ms/epoch - 11ms/step
# Epoch 26/200
# 88/88 - 1s - loss: 0.0499 - accuracy: 0.9822 - val_loss: 0.1646 - val_accuracy: 0.9419 - lr: 0.0017 - 1s/epoch - 11ms/step
# Epoch 27/200
# 88/88 - 1s - loss: 0.0467 - accuracy: 0.9793 - val_loss: 0.1648 - val_accuracy: 0.9419 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 28/200
# 88/88 - 1s - loss: 0.0411 - accuracy: 0.9829 - val_loss: 0.1654 - val_accuracy: 0.9355 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 29/200
# 88/88 - 1s - loss: 0.0508 - accuracy: 0.9779 - val_loss: 0.1646 - val_accuracy: 0.9355 - lr: 0.0010 - 1s/epoch - 12ms/step
# Epoch 30/200
# 88/88 - 1s - loss: 0.0424 - accuracy: 0.9836 - val_loss: 0.1656 - val_accuracy: 0.9355 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 31/200
# 88/88 - 1s - loss: 0.0505 - accuracy: 0.9800 - val_loss: 0.1648 - val_accuracy: 0.9355 - lr: 6.0466e-04 - 1s/epoch - 12ms/step
# Epoch 32/200
# 88/88 - 1s - loss: 0.0425 - accuracy: 0.9857 - val_loss: 0.1660 - val_accuracy: 0.9355 - lr: 6.0466e-04 - 978ms/epoch - 11ms/step
# Epoch 33/200
# 88/88 - 1s - loss: 0.0462 - accuracy: 0.9843 - val_loss: 0.1663 - val_accuracy: 0.9355 - lr: 3.6280e-04 - 976ms/epoch - 11ms/step
# Epoch 34/200
# 88/88 - 1s - loss: 0.0421 - accuracy: 0.9843 - val_loss: 0.1661 - val_accuracy: 0.9355 - lr: 3.6280e-04 - 1s/epoch - 14ms/step
# Epoch 35/200
# 88/88 - 2s - loss: 0.0433 - accuracy: 0.9814 - val_loss: 0.1664 - val_accuracy: 0.9355 - lr: 3.6280e-04 - 2s/epoch - 18ms/step
# Epoch 36/200
# 88/88 - 1s - loss: 0.0451 - accuracy: 0.9807 - val_loss: 0.1661 - val_accuracy: 0.9355 - lr: 2.1768e-04 - 1s/epoch - 14ms/step
# Epoch 37/200
# 88/88 - 1s - loss: 0.0434 - accuracy: 0.9850 - val_loss: 0.1667 - val_accuracy: 0.9355 - lr: 2.1768e-04 - 987ms/epoch - 11ms/step
# Epoch 38/200
# 88/88 - 1s - loss: 0.0415 - accuracy: 0.9864 - val_loss: 0.1671 - val_accuracy: 0.9355 - lr: 2.1768e-04 - 1s/epoch - 12ms/step
# Epoch 39/200
# 88/88 - 1s - loss: 0.0468 - accuracy: 0.9829 - val_loss: 0.1668 - val_accuracy: 0.9355 - lr: 1.3061e-04 - 998ms/epoch - 11ms/step
# Epoch 40/200
# 88/88 - 1s - loss: 0.0406 - accuracy: 0.9850 - val_loss: 0.1669 - val_accuracy: 0.9355 - lr: 1.3061e-04 - 1s/epoch - 13ms/step
# Epoch 41/200
# 88/88 - 2s - loss: 0.0408 - accuracy: 0.9872 - val_loss: 0.1668 - val_accuracy: 0.9355 - lr: 1.3061e-04 - 2s/epoch - 19ms/step
# Epoch 42/200
# 88/88 - 2s - loss: 0.0441 - accuracy: 0.9843 - val_loss: 0.1670 - val_accuracy: 0.9355 - lr: 7.8364e-05 - 2s/epoch - 26ms/step
# Epoch 43/200
# 88/88 - 2s - loss: 0.0418 - accuracy: 0.9836 - val_loss: 0.1671 - val_accuracy: 0.9355 - lr: 7.8364e-05 - 2s/epoch - 20ms/step
# Epoch 44/200
# 88/88 - 2s - loss: 0.0428 - accuracy: 0.9814 - val_loss: 0.1671 - val_accuracy: 0.9355 - lr: 7.8364e-05 - 2s/epoch - 24ms/step
# Epoch 45/200
# 88/88 - 2s - loss: 0.0435 - accuracy: 0.9836 - val_loss: 0.1671 - val_accuracy: 0.9355 - lr: 4.7018e-05 - 2s/epoch - 21ms/step
# Epoch 46/200
# 88/88 - 1s - loss: 0.0482 - accuracy: 0.9807 - val_loss: 0.1671 - val_accuracy: 0.9355 - lr: 4.7018e-05 - 1s/epoch - 16ms/step
# 155/155 [==============================] - 0s 2ms/step

# %%
from statistics import mean, stdev
print(mean(ACC_collecton),'±',stdev(ACC_collecton))
print(mean(BACC_collecton),'±',stdev(BACC_collecton))
print(mean(Sn_collecton),'±',stdev(Sn_collecton))
print(mean(Sp_collecton),'±',stdev(Sp_collecton))
print(mean(MCC_collecton),'±',stdev(MCC_collecton))
print(mean(AUC_collecton),'±',stdev(AUC_collecton))
# Out:
# 0.9543713813068652 ± 0.014374659368985339
# 0.9559342136337798 ± 0.014179244685304012
# 0.9790912802395684 ± 0.017223767549981985
# 0.9327771470279913 ± 0.02387450707171604
# 0.9101475372939533 ± 0.028114384436897767
# 0.9847340739149721 ± 0.007996539335243049

# %%
ACC_collecton
# Out:
# [0.9815950920245399]

# %% [markdown]
# ### model evaluation in test dataset

# %%
# result collection list
ACC_collecton = []
BACC_collecton = []
Sn_collecton = []
Sp_collecton = []
MCC_collecton = []
AUC_collecton = []
model, model_history = ESM_CNN(X_train, y_train, X_test , y_test)
# confusion matrix 
predicted_class= []
predicted_protability = model.predict(X_test,batch_size=1)
for i in range(predicted_protability.shape[0]):
  index = np.where(predicted_protability[i] == np.amax(predicted_protability[i]))[0][0]
  predicted_class.append(index)
predicted_class = np.array(predicted_class)
y_true = y_test    
from sklearn.metrics import confusion_matrix
import math
# np.ravel() return a flatten 1D array
TP, FP, FN, TN = confusion_matrix(y_true, predicted_class).ravel() # shape [ [True-Positive, False-positive], [False-negative, True-negative] ]
ACC = (TP+TN)/(TP+TN+FP+FN)
ACC_collecton.append(ACC)
Sn_collecton.append(TP/(TP+FN))
Sp_collecton.append(TN/(TN+FP))
MCC = (TP*TN-FP*FN)/math.pow(((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN)),0.5)
MCC_collecton.append(MCC)
BACC_collecton.append(0.5*TP/(TP+FN)+0.5*TN/(TN+FP))
from sklearn.metrics import roc_auc_score
AUC = roc_auc_score(y_test, predicted_protability[:,1])
AUC_collecton.append(AUC)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 64/64 - 2s - loss: 1.0690 - accuracy: 0.6706 - val_loss: 0.6979 - val_accuracy: 0.5000 - lr: 0.1000 - 2s/epoch - 36ms/step
# Epoch 2/200
# 64/64 - 1s - loss: 0.4084 - accuracy: 0.8216 - val_loss: 0.6965 - val_accuracy: 0.5000 - lr: 0.1000 - 725ms/epoch - 11ms/step
# Epoch 3/200
# 64/64 - 1s - loss: 0.3796 - accuracy: 0.8451 - val_loss: 0.6964 - val_accuracy: 0.5000 - lr: 0.0600 - 662ms/epoch - 10ms/step
# Epoch 4/200
# 64/64 - 1s - loss: 0.3016 - accuracy: 0.8627 - val_loss: 0.6818 - val_accuracy: 0.5326 - lr: 0.0600 - 630ms/epoch - 10ms/step
# Epoch 5/200
# 64/64 - 1s - loss: 0.3048 - accuracy: 0.8647 - val_loss: 0.6315 - val_accuracy: 0.6413 - lr: 0.0600 - 639ms/epoch - 10ms/step
# Epoch 6/200
# 64/64 - 1s - loss: 0.2687 - accuracy: 0.8902 - val_loss: 0.5485 - val_accuracy: 0.8152 - lr: 0.0360 - 617ms/epoch - 10ms/step
# Epoch 7/200
# 64/64 - 1s - loss: 0.2474 - accuracy: 0.9059 - val_loss: 0.4456 - val_accuracy: 0.8587 - lr: 0.0360 - 615ms/epoch - 10ms/step
# Epoch 8/200
# 64/64 - 1s - loss: 0.2153 - accuracy: 0.9020 - val_loss: 0.3283 - val_accuracy: 0.8587 - lr: 0.0360 - 616ms/epoch - 10ms/step
# Epoch 9/200
# 64/64 - 1s - loss: 0.1962 - accuracy: 0.9196 - val_loss: 0.3098 - val_accuracy: 0.8587 - lr: 0.0216 - 605ms/epoch - 9ms/step
# Epoch 10/200
# 64/64 - 1s - loss: 0.1905 - accuracy: 0.9176 - val_loss: 0.3258 - val_accuracy: 0.8696 - lr: 0.0216 - 679ms/epoch - 11ms/step
# Epoch 11/200
# 64/64 - 1s - loss: 0.1685 - accuracy: 0.9255 - val_loss: 0.3381 - val_accuracy: 0.8913 - lr: 0.0216 - 640ms/epoch - 10ms/step
# Epoch 12/200
# 64/64 - 1s - loss: 0.1447 - accuracy: 0.9431 - val_loss: 0.3734 - val_accuracy: 0.8804 - lr: 0.0130 - 610ms/epoch - 10ms/step
# Epoch 13/200
# 64/64 - 1s - loss: 0.1545 - accuracy: 0.9314 - val_loss: 0.3688 - val_accuracy: 0.8804 - lr: 0.0130 - 671ms/epoch - 10ms/step
# Epoch 14/200
# 64/64 - 1s - loss: 0.1331 - accuracy: 0.9431 - val_loss: 0.3630 - val_accuracy: 0.8696 - lr: 0.0130 - 624ms/epoch - 10ms/step
# Epoch 15/200
# 64/64 - 1s - loss: 0.1273 - accuracy: 0.9510 - val_loss: 0.4105 - val_accuracy: 0.8804 - lr: 0.0078 - 669ms/epoch - 10ms/step
# Epoch 16/200
# 64/64 - 1s - loss: 0.1340 - accuracy: 0.9373 - val_loss: 0.4084 - val_accuracy: 0.8696 - lr: 0.0078 - 641ms/epoch - 10ms/step
# Epoch 17/200
# 64/64 - 1s - loss: 0.1117 - accuracy: 0.9529 - val_loss: 0.4547 - val_accuracy: 0.8804 - lr: 0.0078 - 646ms/epoch - 10ms/step
# Epoch 18/200
# 64/64 - 1s - loss: 0.1096 - accuracy: 0.9588 - val_loss: 0.4539 - val_accuracy: 0.8804 - lr: 0.0047 - 960ms/epoch - 15ms/step
# Epoch 19/200
# 64/64 - 1s - loss: 0.1157 - accuracy: 0.9471 - val_loss: 0.4475 - val_accuracy: 0.8804 - lr: 0.0047 - 953ms/epoch - 15ms/step
# Epoch 20/200
# 64/64 - 1s - loss: 0.1074 - accuracy: 0.9510 - val_loss: 0.4291 - val_accuracy: 0.8696 - lr: 0.0047 - 917ms/epoch - 14ms/step
# Epoch 21/200
# 64/64 - 1s - loss: 0.1029 - accuracy: 0.9588 - val_loss: 0.4371 - val_accuracy: 0.8696 - lr: 0.0028 - 619ms/epoch - 10ms/step
# Epoch 22/200
# 64/64 - 1s - loss: 0.0950 - accuracy: 0.9647 - val_loss: 0.4607 - val_accuracy: 0.8696 - lr: 0.0028 - 609ms/epoch - 10ms/step
# Epoch 23/200
# 64/64 - 1s - loss: 0.1026 - accuracy: 0.9490 - val_loss: 0.4779 - val_accuracy: 0.8696 - lr: 0.0028 - 631ms/epoch - 10ms/step
# Epoch 24/200
# 64/64 - 1s - loss: 0.0949 - accuracy: 0.9608 - val_loss: 0.4573 - val_accuracy: 0.8696 - lr: 0.0017 - 585ms/epoch - 9ms/step
# Epoch 25/200
# 64/64 - 1s - loss: 0.0880 - accuracy: 0.9745 - val_loss: 0.4600 - val_accuracy: 0.8696 - lr: 0.0017 - 640ms/epoch - 10ms/step
# Epoch 26/200
# 64/64 - 1s - loss: 0.0966 - accuracy: 0.9569 - val_loss: 0.4677 - val_accuracy: 0.8696 - lr: 0.0017 - 618ms/epoch - 10ms/step
# Epoch 27/200
# 64/64 - 1s - loss: 0.0938 - accuracy: 0.9608 - val_loss: 0.4667 - val_accuracy: 0.8696 - lr: 0.0010 - 629ms/epoch - 10ms/step
# Epoch 28/200
# 64/64 - 1s - loss: 0.0975 - accuracy: 0.9549 - val_loss: 0.4665 - val_accuracy: 0.8696 - lr: 0.0010 - 669ms/epoch - 10ms/step
# Epoch 29/200
# 64/64 - 1s - loss: 0.0939 - accuracy: 0.9529 - val_loss: 0.4684 - val_accuracy: 0.8696 - lr: 0.0010 - 661ms/epoch - 10ms/step
# Epoch 30/200
# 64/64 - 1s - loss: 0.0963 - accuracy: 0.9608 - val_loss: 0.4675 - val_accuracy: 0.8696 - lr: 6.0466e-04 - 600ms/epoch - 9ms/step
# Epoch 31/200
# 64/64 - 1s - loss: 0.1063 - accuracy: 0.9549 - val_loss: 0.4652 - val_accuracy: 0.8696 - lr: 6.0466e-04 - 650ms/epoch - 10ms/step
# Epoch 32/200
# 64/64 - 1s - loss: 0.0947 - accuracy: 0.9627 - val_loss: 0.4644 - val_accuracy: 0.8696 - lr: 6.0466e-04 - 665ms/epoch - 10ms/step
# Epoch 33/200
# 64/64 - 1s - loss: 0.0890 - accuracy: 0.9627 - val_loss: 0.4660 - val_accuracy: 0.8696 - lr: 3.6280e-04 - 633ms/epoch - 10ms/step
# Epoch 34/200
# 64/64 - 1s - loss: 0.0804 - accuracy: 0.9706 - val_loss: 0.4698 - val_accuracy: 0.8696 - lr: 3.6280e-04 - 642ms/epoch - 10ms/step
# Epoch 35/200
# 64/64 - 1s - loss: 0.0939 - accuracy: 0.9627 - val_loss: 0.4669 - val_accuracy: 0.8696 - lr: 3.6280e-04 - 654ms/epoch - 10ms/step
# Epoch 36/200
# 64/64 - 1s - loss: 0.0848 - accuracy: 0.9686 - val_loss: 0.4668 - val_accuracy: 0.8696 - lr: 2.1768e-04 - 714ms/epoch - 11ms/step
# Epoch 37/200
# 64/64 - 1s - loss: 0.0887 - accuracy: 0.9647 - val_loss: 0.4663 - val_accuracy: 0.8696 - lr: 2.1768e-04 - 919ms/epoch - 14ms/step
# Epoch 38/200
# 64/64 - 1s - loss: 0.0816 - accuracy: 0.9706 - val_loss: 0.4684 - val_accuracy: 0.8696 - lr: 2.1768e-04 - 951ms/epoch - 15ms/step
# Epoch 39/200
# 64/64 - 1s - loss: 0.0866 - accuracy: 0.9647 - val_loss: 0.4663 - val_accuracy: 0.8696 - lr: 1.3061e-04 - 877ms/epoch - 14ms/step
# Epoch 40/200
# 64/64 - 1s - loss: 0.0884 - accuracy: 0.9647 - val_loss: 0.4681 - val_accuracy: 0.8696 - lr: 1.3061e-04 - 661ms/epoch - 10ms/step
# Epoch 41/200
# 64/64 - 1s - loss: 0.1044 - accuracy: 0.9490 - val_loss: 0.4702 - val_accuracy: 0.8696 - lr: 1.3061e-04 - 600ms/epoch - 9ms/step
# Epoch 42/200
# 64/64 - 1s - loss: 0.0893 - accuracy: 0.9647 - val_loss: 0.4702 - val_accuracy: 0.8696 - lr: 7.8364e-05 - 633ms/epoch - 10ms/step
# Epoch 43/200
# 64/64 - 1s - loss: 0.0925 - accuracy: 0.9667 - val_loss: 0.4700 - val_accuracy: 0.8696 - lr: 7.8364e-05 - 653ms/epoch - 10ms/step
# Epoch 44/200
# 64/64 - 1s - loss: 0.1006 - accuracy: 0.9529 - val_loss: 0.4693 - val_accuracy: 0.8696 - lr: 7.8364e-05 - 653ms/epoch - 10ms/step
# Epoch 45/200
# 64/64 - 1s - loss: 0.0892 - accuracy: 0.9588 - val_loss: 0.4693 - val_accuracy: 0.8696 - lr: 4.7018e-05 - 622ms/epoch - 10ms/step
# Epoch 46/200
# 64/64 - 1s - loss: 0.1007 - accuracy: 0.9549 - val_loss: 0.4698 - val_accuracy: 0.8696 - lr: 4.7018e-05 - 603ms/epoch - 9ms/step
# Epoch 47/200
# 64/64 - 1s - loss: 0.0923 - accuracy: 0.9667 - val_loss: 0.4696 - val_accuracy: 0.8696 - lr: 4.7018e-05 - 616ms/epoch - 10ms/step
# Epoch 48/200
# 64/64 - 1s - loss: 0.0900 - accuracy: 0.9765 - val_loss: 0.4700 - val_accuracy: 0.8696 - lr: 2.8211e-05 - 624ms/epoch - 10ms/step
# Epoch 49/200
# 64/64 - 1s - loss: 0.0757 - accuracy: 0.9804 - val_loss: 0.4699 - val_accuracy: 0.8696 - lr: 2.8211e-05 - 653ms/epoch - 10ms/step
# Epoch 50/200
# 64/64 - 1s - loss: 0.0944 - accuracy: 0.9588 - val_loss: 0.4695 - val_accuracy: 0.8696 - lr: 2.8211e-05 - 617ms/epoch - 10ms/step
# Epoch 51/200
# 64/64 - 1s - loss: 0.0963 - accuracy: 0.9569 - val_loss: 0.4700 - val_accuracy: 0.8696 - lr: 1.6927e-05 - 616ms/epoch - 10ms/step
# 92/92 [==============================] - 0s 2ms/step

# %%
print(ACC_collecton[0])
print(BACC_collecton[0])
print(Sn_collecton[0])
print(Sp_collecton[0])
print(MCC_collecton[0])
print(AUC_collecton[0])
# Out:
# 0.9487179487179487
# 0.9523809523809523
# 1.0
# 0.9047619047619048
# 0.9023778112773576
# 0.99375

# %%
model.save('AF_tensorflow_model',save_format = 'tf') 
# !zip -r /content/AF_tensorflow_model.zip /content/AF_tensorflow_model
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
#   adding: content/AF_tensorflow_model/ (stored 0%)
#   adding: content/AF_tensorflow_model/keras_metadata.pb (deflated 90%)
#   adding: content/AF_tensorflow_model/assets/ (stored 0%)
#   adding: content/AF_tensorflow_model/saved_model.pb (deflated 88%)
#   adding: content/AF_tensorflow_model/variables/ (stored 0%)
#   adding: content/AF_tensorflow_model/variables/variables.data-00000-of-00001 (deflated 37%)
#   adding: content/AF_tensorflow_model/variables/variables.index (deflated 64%)
#   adding: content/AF_tensorflow_model/fingerprint.pb (stored 0%)

# %% [markdown]
# ### t-SNE graph making

# %%
# loading datasset
X_train_data_name = 'AF_train_esm2_t6_8M_UR50D_unified_320_dimension.csv'
X_train_data = pd.read_csv(X_train_data_name,header=0, index_col = 0,delimiter=',')
X_test_data_name = 'AF_test_esm2_t6_8M_UR50D_unified_320_dimension.csv'
X_test_data = pd.read_csv(X_test_data_name,header=0, index_col = 0,delimiter=',')
X_train = np.array(X_train_data)
X_test = np.array(X_test_data)
# training dataset loading
dataset = pd.read_excel('AF_train.xlsx',na_filter = False) # take care the NA sequence problem
# loading the y dataset for model development 
y_train = dataset['label']
y_train = np.array(y_train) # transformed as np.array for CNN model
# training dataset loading
dataset = pd.read_excel('AF_test.xlsx',na_filter = False) # take care the NA sequence problem
# loading the y dataset for model development 
y_test = dataset['label']
y_test = np.array(y_test) # transformed as np.array for CNN model
# normalize the X data range (just )
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train) # normalize X to 0-1 range 
X_test = scaler.transform(X_test)
# concatenate the dataset
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)

from sklearn.manifold import TSNE
from keras.datasets import mnist
from sklearn.datasets import load_iris
from numpy import reshape
import seaborn as sns
import pandas as pd  
tsne = TSNE(n_components=2, verbose=0, perplexity= 25, learning_rate='auto',n_iter = 5000,random_state=123)
z = tsne.fit_transform(X) 
df = pd.DataFrame()
df["comp-1"] = z[:,0]
df["comp-2"] = z[:,1]
y_new_label=[]
for i in y:
    if i == 0:
        y_new_label.append('Active')
    if i == 1:
        y_new_label.append('Inactive')
df["y"] = y_new_label
graph = sns.scatterplot(data=df, x="comp-1", y="comp-2", hue=y_new_label,
                palette='BrBG_r', legend='full')
graph_for_output = graph.get_figure()
graph_for_output.savefig('15.AF_t-SNE.png', dpi=300)
df.to_excel('15.AF_t-SNE.xlsx')
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
# !pip install umap-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.8/dist-packages (0.5.3)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (0.5.8)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (1.21.6)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (0.56.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from umap-learn) (1.7.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from umap-learn) (4.64.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn) (6.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pynndescent>=0.5->umap-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->umap-learn) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.49->umap-learn) (3.12.1)

# %%
import umap
import seaborn as sns
# concatenate the dataset
X = np.concatenate((X_train, X_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)
embedding = umap.UMAP(n_neighbors=20).fit_transform(X, y=y) # two dimension
df = pd.DataFrame()
df["comp-1"] = embedding[:,0]
df["comp-2"] = embedding[:,1]
y_new_label=[]
for i in y:
    if i == 0:
        y_new_label.append('Active')
    if i == 1:
        y_new_label.append('Inactive')
df["y"] = y_new_label
graph = sns.scatterplot(data=df, x="comp-1", y="comp-2", hue=y_new_label,
                palette='YlOrRd_r', legend='full')
graph_for_output = graph.get_figure()
graph_for_output.savefig('15.AF_UMAP.png', dpi=300)
df.to_excel('15.AF_UMAP.xlsx')
